# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter
import matplotlib as mpl

import numpy as np
import time
from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:0

# %%
loss_thresh = 25000
level = "_low"
label = "Burgers_stan" + level

T0 = 300
pi = 3.14
rho = 1
c_p = 1
k = 0.001


x = np.linspace(-1,1,500).reshape(-1,1)
t = np.linspace(0,10,500).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

# bound_pts_1 = (X == 0).reshape(-1,)
# bound_pts_2 = np.logical_and(Y == 0,X != 0).reshape(-1,)
# bound_pts_3 = np.logical_and(X == 1,Y != 0).reshape(-1,) 
# bound_pts_4 = np.logical_and(Y == 1,X != 1).reshape(-1,) 

# xy_bound_1 = xy[bound_pts_1,:]
# xy_bound_2 = xy[bound_pts_2,:]
# xy_bound_3 = xy[bound_pts_3,:]
# xy_bound_4 = xy[bound_pts_4,:]

# u_bound_1 = 1000*np.ones((np.shape(xy_bound_1)[0],1))
# u_bound_2 = 800*np.ones((np.shape(xy_bound_2)[0],1))
# u_bound_3 = 500*np.ones((np.shape(xy_bound_3)[0],1))
# u_bound_4 = np.zeros((np.shape(xy_bound_4)[0],1))

# xy_bound = np.vstack((xy_bound_1,xy_bound_2,xy_bound_3,xy_bound_4))
# u_bound = np.vstack((u_bound_1,u_bound_2,u_bound_3,u_bound_4))

# xy_test_tensor = torch.from_numpy(xy).float().to(device)

lb_xt = xt[0]
ub_xt = xt[-1]

# %%
# data = scipy.io.loadmat('burgers_shock.mat') 

# pi = torch.from_numpy(np.array(np.pi)).double().to(device)

# x = np.array(data['x'])
# t = np.array(data['t'])

# X,T = np.meshgrid(x,t)

# X = X.flatten('F').reshape(-1,1)
# T = T.flatten('F').reshape(-1,1)
  
# xt = np.hstack((X,T))

# u_true = np.array(data['usol'][:])

# xt_test_tensor = torch.from_numpy(xt).float().to(device)
# u_true_norm = np.linalg.norm(u_true,2)

# %%
def trainingdata(N_T,N_f,seed):
    '''Boundary Conditions''' 
    
    np.random.seed(seed)
    
    x_l = x[0]*np.ones((N_T,1))
    t_l = np.random.uniform(t[0],t[-1],(N_T,1))
    xt_l = np.hstack((x_l,t_l))
    u_l = T0*np.ones((N_T,1))
    
    x_r = x[-1]*np.ones((N_T,1))
    t_r = np.random.uniform(t[0],t[-1],(N_T,1))
    xt_r = np.hstack((x_r,t_r))
    u_r = T0*np.ones((N_T,1))
    
    x_0 = np.random.uniform(x[0],x[-1],(N_T,1))
    t_0 = t[0]*np.ones((N_T,1))
    xt_0 = np.hstack((x_0,t_0))
    u_0 = T0*np.ones((N_T,1))
    
    xt_BC = np.vstack((xt_l,xt_r,xt_0)) #choose indices from  set 'idx' (x,t)
    u_BC = np.vstack((u_l,u_r,u_0))
    
    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    x01 = np.array([[0.0,1.0],[0.0,1.0]])
    sampling = LHS(xlimits=x01,random_state =seed)
    samples = sampling(N_f)
    
    xt_coll = lb_xt + (ub_xt - lb_xt)*samples
    
    #Additional Collocation 
    # x_c_coll = np.random.normal(0,0.05,(N_T,1))
    # t_c_coll = np.abs(np.random.normal(0,0.05,(N_T,1)))
    # xt_c_coll = np.hstack((x_c_coll,t_c_coll))
    
    
    xt_coll = np.vstack((xt_coll, xt_BC)) # append training points to collocation points 

    return xt_coll, xt_BC, u_BC

# %%
class Sequentialmodel(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

     
        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        self.iter = 0
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)   
        
        beta_mean = 1.0*torch.ones((50,len(layers)-2))
        beta_std = 0.1*torch.ones((50,len(layers)-2))
        
        self.beta = Parameter(torch.normal(beta_mean,beta_std))
        self.beta.requiresGrad = True
            
    'foward pass'
    def forward(self,xy):
        if torch.is_tensor(xy) != True:         
            xy = torch.from_numpy(xy)                
        
        ubxy = torch.from_numpy(ub_xt).float().to(device)
        lbxy = torch.from_numpy(lb_xt).float().to(device)
    
                      
        #preprocessing input 
        xy = 2.0*(xy - lbxy)/(ubxy - lbxy) - 1.0
        
        #convert to float
        a = xy.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            z1 =self.activation(z)
            a = z1 + self.beta[:,i]*z*z1
       
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xy,u):
                
        loss_bc = self.loss_function(self.forward(xy), u)
                
        return loss_bc
    
    
    def loss_heat(self, xy_coll,f_hat):
        g = xy_coll.clone()             
        g.requires_grad = True
        u = self.forward(g) 
        
        u_x_y = autograd.grad(u,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        du_dx = u_x_y[:,[0]]
        
        #Heat source Gaussian Distributed in x and t
        sigma_x = 0.02
        sigma_t = 0.1
        exp_term1 = torch.square(g[:,0].reshape(-1,1))/sigma_x**2
        exp_term2 =  torch.square(g[:,1].reshape(-1,1))/sigma_t**2
        
        Q = torch.exp(-0.5*(exp_term1 + exp_term2))/(np.sqrt(2*pi*sigma_x*sigma_t)) 
        
        f = k*du_dx - Q
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
        
    
    def loss_PDE(self, xy_coll, f_hat):
        
        g = xy_coll.clone()             
        g.requires_grad = True
        u = self.forward(g) 
        
        u_x_y = autograd.grad(u,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        u_xx_yy = autograd.grad(u_x_y,g,torch.ones(xy_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        du_dx = u_x_y[:,[0]]
        du_dt = u_x_y[:,[1]]
        
        d2u_dx2 = u_xx_yy[:,[0]]
        
        #Heat source Gaussian Distributed in x and t
        sigma_x = 0.02
        sigma_t = 0.1
        exp_term1 = torch.square(g[:,0].reshape(-1,1))/sigma_x**2
        exp_term2 =  torch.square(g[:,1].reshape(-1,1))/sigma_t**2
        
        Q = 100.0*torch.exp(-0.5*(exp_term1 + exp_term2))/(np.sqrt(2*pi*sigma_x*sigma_t)) 
        
        f = rho*c_p*du_dt - k*d2u_dx2 - Q
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
    
    def loss(self,xy_BC,u_BC,xy_coll,f_hat):

        loss_BC = self.loss_BC(xy_BC,u_BC)
        loss_f = self.loss_PDE(xy_coll,f_hat)
        loss_heat = self.loss_heat(xy_coll,f_hat)
        
        loss_val = loss_BC + loss_f #+ loss_heat
        
        return loss_val
         
    'test neural network'
    def test(self):
        # u_pred = self.forward(xt_test_tensor)
        # u_pred = u_pred.cpu().detach().numpy()
        u_pred = 0
   
        return u_pred

    def test_loss(self):
        u_pred = self.test()
        
        # test_mse = np.mean(np.square(u_pred.reshape(-1,1) - u_true.reshape(-1,1)))
        # test_re = np.linalg.norm(u_pred.reshape(-1,1) - u_true.reshape(-1,1),2)/u_true_norm
        test_mse = 0
        test_re = 0
        
        return test_mse, test_re

# %%
def data_update(loss_np):
    train_loss.append(loss_np)

    
    test_mse, test_re = PINN.test_loss()
    test_mse_loss.append(test_mse)
    test_re_loss.append(test_re)

# %%
def train_step(xy_BC,u_BC,xy_coll,f_hat,seed):

    def closure():
        optimizer.zero_grad()
        loss = PINN.loss(xy_BC,u_BC,xy_coll,f_hat)
        loss.backward()
        #print(loss.cpu().detach().numpy())
        return loss

    optimizer.step(closure)

# %%
def train_model(max_iter,rep): 
    print(rep) 
    torch.manual_seed(rep*9)
    start_time = time.time() 
    thresh_flag = 0

    xy_coll_np_array, xy_BC_np_array, u_BC_np_array = trainingdata(N_T,N_f,rep*22)
        
    xy_coll = torch.from_numpy(xy_coll_np_array).float().to(device)
    xy_BC = torch.from_numpy(xy_BC_np_array).float().to(device)
    u_BC = torch.from_numpy(u_BC_np_array).float().to(device)
        
    f_hat = torch.zeros(xy_coll.shape[0],1).to(device)
    

    for i in range(max_iter):
        train_step(xy_BC,u_BC,xy_coll,f_hat,i)
        loss_np = PINN.loss(xy_BC,u_BC,xy_coll,f_hat).cpu().detach().numpy()
        
        if(thresh_flag == 0):
            if(loss_np < loss_thresh):
                time_threshold[rep] = time.time() - start_time
                epoch_threshold[rep] = i+1          
                thresh_flag = 1       
        data_update(loss_np)
        
        print(i,"Train Loss",train_loss[-1],"Test MSE",test_mse_loss[-1],"Test RE",test_re_loss[-1])   
        
    elapsed_time[rep] = time.time() - start_time  
    print('Training time: %.2f' % (elapsed_time[rep]))

# %%
max_reps = 1
max_iter = 300 #200

train_loss_full = []
test_mse_full = []
test_re_full = []

elapsed_time= np.zeros((max_reps,1))
time_threshold = np.empty((max_reps,1))
time_threshold[:] = np.nan
epoch_threshold = max_iter*np.ones((max_reps,1))



N_T = 500 #Total number of data points for 'y'
N_f = 10000 #Total number of collocation points 


for reps in range(max_reps):
    print(label)
    print(reps)
    train_loss = []
    test_mse_loss = []
    test_re_loss = []
 
    
    torch.manual_seed(reps*36)
    
    layers = np.array([2,50,50,50,50,50,1]) #9 hidden layers

    PINN = Sequentialmodel(layers)
   
    PINN.to(device)

    'Neural Network Summary'
    print(PINN)

    params = list(PINN.parameters())
    
    optimizer = torch.optim.LBFGS(PINN.parameters(), lr=1, 
                              max_iter = 20, 
                              max_eval = 30, 
                              tolerance_grad = 1e-08, 
                              tolerance_change = 1e-08, 
                              history_size = 100, 
                              line_search_fn = 'strong_wolfe')



   
    
    nan_flag = train_model(max_iter,reps)
    
    
    torch.save(PINN.state_dict(),label+'_'+str(reps)+'.pt')
    train_loss_full.append(train_loss)
    test_mse_full.append(test_mse_loss)
    test_re_full.append(test_re_loss)
    #elapsed_time[reps] = time.time() - start_time



    print('Training time: %.2f' % (elapsed_time[reps]))
    
mdic = {"train_loss": train_loss_full,"test_mse_loss": test_mse_full,"test_re_loss": test_re_full,"Time": elapsed_time, "label": label,"Thresh Time": time_threshold,"Thresh epoch": epoch_threshold}
savemat(label+'.mat', mdic)
# Out:
# Burgers_stan_low
# 0
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# 0
# 0 Train Loss 569.72205 Test MSE 0 Test RE 0
# 1 Train Loss 505.29922 Test MSE 0 Test RE 0
# 2 Train Loss 500.57422 Test MSE 0 Test RE 0
# 3 Train Loss 496.2977 Test MSE 0 Test RE 0
# 4 Train Loss 489.15042 Test MSE 0 Test RE 0
# 5 Train Loss 460.2588 Test MSE 0 Test RE 0
# 6 Train Loss 398.4697 Test MSE 0 Test RE 0
# 7 Train Loss 220.2607 Test MSE 0 Test RE 0
# 8 Train Loss 131.4117 Test MSE 0 Test RE 0
# 9 Train Loss 80.592804 Test MSE 0 Test RE 0
# 10 Train Loss 57.12634 Test MSE 0 Test RE 0
# 11 Train Loss 42.409733 Test MSE 0 Test RE 0
# 12 Train Loss 30.617184 Test MSE 0 Test RE 0
# 13 Train Loss 22.467323 Test MSE 0 Test RE 0
# 14 Train Loss 18.064781 Test MSE 0 Test RE 0
# 15 Train Loss 12.137897 Test MSE 0 Test RE 0
# 16 Train Loss 9.272828 Test MSE 0 Test RE 0
# 17 Train Loss 6.6019516 Test MSE 0 Test RE 0
# 18 Train Loss 4.9215713 Test MSE 0 Test RE 0
# 19 Train Loss 3.770971 Test MSE 0 Test RE 0
# 20 Train Loss 3.2448637 Test MSE 0 Test RE 0
# 21 Train Loss 2.7744496 Test MSE 0 Test RE 0
# 22 Train Loss 2.4686618 Test MSE 0 Test RE 0
# 23 Train Loss 2.237181 Test MSE 0 Test RE 0
# 24 Train Loss 2.0496283 Test MSE 0 Test RE 0
# 25 Train Loss 1.8585464 Test MSE 0 Test RE 0
# 26 Train Loss 1.7407775 Test MSE 0 Test RE 0
# 27 Train Loss 1.627386 Test MSE 0 Test RE 0
# 28 Train Loss 1.504566 Test MSE 0 Test RE 0
# 29 Train Loss 1.3299328 Test MSE 0 Test RE 0
# 30 Train Loss 1.255898 Test MSE 0 Test RE 0
# 31 Train Loss 1.153674 Test MSE 0 Test RE 0
# 32 Train Loss 1.0498068 Test MSE 0 Test RE 0
# 33 Train Loss 0.9948059 Test MSE 0 Test RE 0
# 34 Train Loss 0.93142796 Test MSE 0 Test RE 0
# 35 Train Loss 0.86346793 Test MSE 0 Test RE 0
# 36 Train Loss 0.79801565 Test MSE 0 Test RE 0
# 37 Train Loss 0.7689047 Test MSE 0 Test RE 0
# 38 Train Loss 0.69166416 Test MSE 0 Test RE 0
# 39 Train Loss 0.62703264 Test MSE 0 Test RE 0
# 40 Train Loss 0.5861283 Test MSE 0 Test RE 0
# 41 Train Loss 0.5259747 Test MSE 0 Test RE 0
# 42 Train Loss 0.4739582 Test MSE 0 Test RE 0
# 43 Train Loss 0.42414618 Test MSE 0 Test RE 0
# 44 Train Loss 0.4073184 Test MSE 0 Test RE 0
# 45 Train Loss 0.3744786 Test MSE 0 Test RE 0
# 46 Train Loss 0.35244036 Test MSE 0 Test RE 0
# 47 Train Loss 0.3314222 Test MSE 0 Test RE 0
# 48 Train Loss 0.30319464 Test MSE 0 Test RE 0
# 49 Train Loss 0.2833133 Test MSE 0 Test RE 0
# 50 Train Loss 0.25372922 Test MSE 0 Test RE 0
# 51 Train Loss 0.24085367 Test MSE 0 Test RE 0
# 52 Train Loss 0.22571203 Test MSE 0 Test RE 0
# 53 Train Loss 0.21081847 Test MSE 0 Test RE 0
# 54 Train Loss 0.19295889 Test MSE 0 Test RE 0
# 55 Train Loss 0.18550727 Test MSE 0 Test RE 0
# 56 Train Loss 0.16982546 Test MSE 0 Test RE 0
# 57 Train Loss 0.16618657 Test MSE 0 Test RE 0
# 58 Train Loss 0.14928862 Test MSE 0 Test RE 0
# 59 Train Loss 0.14579365 Test MSE 0 Test RE 0
# 60 Train Loss 0.13431586 Test MSE 0 Test RE 0
# 61 Train Loss 0.13119042 Test MSE 0 Test RE 0
# 62 Train Loss 0.11936842 Test MSE 0 Test RE 0
# 63 Train Loss 0.11643215 Test MSE 0 Test RE 0
# 64 Train Loss 0.107942216 Test MSE 0 Test RE 0
# 65 Train Loss 0.105435185 Test MSE 0 Test RE 0
# 66 Train Loss 0.10211321 Test MSE 0 Test RE 0
# 67 Train Loss 0.0940693 Test MSE 0 Test RE 0
# 68 Train Loss 0.092661925 Test MSE 0 Test RE 0
# 69 Train Loss 0.08616534 Test MSE 0 Test RE 0
# 70 Train Loss 0.08311775 Test MSE 0 Test RE 0
# 71 Train Loss 0.08085479 Test MSE 0 Test RE 0
# 72 Train Loss 0.078825004 Test MSE 0 Test RE 0
# 73 Train Loss 0.07378322 Test MSE 0 Test RE 0
# 74 Train Loss 0.07225845 Test MSE 0 Test RE 0
# 75 Train Loss 0.07126843 Test MSE 0 Test RE 0
# 76 Train Loss 0.06685121 Test MSE 0 Test RE 0
# 77 Train Loss 0.06501298 Test MSE 0 Test RE 0
# 78 Train Loss 0.06409075 Test MSE 0 Test RE 0
# 79 Train Loss 0.06270583 Test MSE 0 Test RE 0
# 80 Train Loss 0.060476255 Test MSE 0 Test RE 0
# 81 Train Loss 0.057649728 Test MSE 0 Test RE 0
# 82 Train Loss 0.055905648 Test MSE 0 Test RE 0
# 83 Train Loss 0.053238392 Test MSE 0 Test RE 0
# 84 Train Loss 0.051577482 Test MSE 0 Test RE 0
# 85 Train Loss 0.05013565 Test MSE 0 Test RE 0
# 86 Train Loss 0.048588008 Test MSE 0 Test RE 0
# 87 Train Loss 0.047192477 Test MSE 0 Test RE 0
# 88 Train Loss 0.046030026 Test MSE 0 Test RE 0
# 89 Train Loss 0.044478886 Test MSE 0 Test RE 0
# 90 Train Loss 0.043539174 Test MSE 0 Test RE 0
# 91 Train Loss 0.0428408 Test MSE 0 Test RE 0
# 92 Train Loss 0.042068858 Test MSE 0 Test RE 0
# 93 Train Loss 0.04127893 Test MSE 0 Test RE 0
# 94 Train Loss 0.040178515 Test MSE 0 Test RE 0
# 95 Train Loss 0.03879199 Test MSE 0 Test RE 0
# 96 Train Loss 0.03815583 Test MSE 0 Test RE 0
# 97 Train Loss 0.03717912 Test MSE 0 Test RE 0
# 98 Train Loss 0.03624127 Test MSE 0 Test RE 0
# 99 Train Loss 0.03475711 Test MSE 0 Test RE 0
# 100 Train Loss 0.033860046 Test MSE 0 Test RE 0
# 101 Train Loss 0.033110894 Test MSE 0 Test RE 0
# 102 Train Loss 0.0319625 Test MSE 0 Test RE 0
# 103 Train Loss 0.031150267 Test MSE 0 Test RE 0
# 104 Train Loss 0.03053178 Test MSE 0 Test RE 0
# 105 Train Loss 0.030020276 Test MSE 0 Test RE 0
# 106 Train Loss 0.029168714 Test MSE 0 Test RE 0
# 107 Train Loss 0.028303264 Test MSE 0 Test RE 0
# 108 Train Loss 0.027846294 Test MSE 0 Test RE 0
# 109 Train Loss 0.027466882 Test MSE 0 Test RE 0
# 110 Train Loss 0.026555026 Test MSE 0 Test RE 0
# 111 Train Loss 0.025846295 Test MSE 0 Test RE 0
# 112 Train Loss 0.025524406 Test MSE 0 Test RE 0
# 113 Train Loss 0.025072122 Test MSE 0 Test RE 0
# 114 Train Loss 0.024253983 Test MSE 0 Test RE 0
# 115 Train Loss 0.02375013 Test MSE 0 Test RE 0
# 116 Train Loss 0.023410417 Test MSE 0 Test RE 0
# 117 Train Loss 0.023129713 Test MSE 0 Test RE 0
# 118 Train Loss 0.02296698 Test MSE 0 Test RE 0
# 119 Train Loss 0.022563944 Test MSE 0 Test RE 0
# 120 Train Loss 0.02203154 Test MSE 0 Test RE 0
# 121 Train Loss 0.021488559 Test MSE 0 Test RE 0
# 122 Train Loss 0.020812444 Test MSE 0 Test RE 0
# 123 Train Loss 0.020534607 Test MSE 0 Test RE 0
# 124 Train Loss 0.0201969 Test MSE 0 Test RE 0
# 125 Train Loss 0.019851722 Test MSE 0 Test RE 0
# 126 Train Loss 0.01959124 Test MSE 0 Test RE 0
# 127 Train Loss 0.0194707 Test MSE 0 Test RE 0
# 128 Train Loss 0.019289922 Test MSE 0 Test RE 0
# 129 Train Loss 0.01903238 Test MSE 0 Test RE 0
# 130 Train Loss 0.018597791 Test MSE 0 Test RE 0
# 131 Train Loss 0.0181039 Test MSE 0 Test RE 0
# 132 Train Loss 0.01771504 Test MSE 0 Test RE 0
# 133 Train Loss 0.017456096 Test MSE 0 Test RE 0
# 134 Train Loss 0.01717965 Test MSE 0 Test RE 0
# 135 Train Loss 0.016934725 Test MSE 0 Test RE 0
# 136 Train Loss 0.016758246 Test MSE 0 Test RE 0
# 137 Train Loss 0.016617995 Test MSE 0 Test RE 0
# 138 Train Loss 0.016427167 Test MSE 0 Test RE 0
# 139 Train Loss 0.01605571 Test MSE 0 Test RE 0
# 140 Train Loss 0.01583403 Test MSE 0 Test RE 0
# 141 Train Loss 0.015635569 Test MSE 0 Test RE 0
# 142 Train Loss 0.015532488 Test MSE 0 Test RE 0
# 143 Train Loss 0.01536262 Test MSE 0 Test RE 0
# 144 Train Loss 0.015235651 Test MSE 0 Test RE 0
# 145 Train Loss 0.015076076 Test MSE 0 Test RE 0
# 146 Train Loss 0.014895793 Test MSE 0 Test RE 0
# 147 Train Loss 0.014708493 Test MSE 0 Test RE 0
# 148 Train Loss 0.0145164905 Test MSE 0 Test RE 0
# 149 Train Loss 0.014402808 Test MSE 0 Test RE 0
# 150 Train Loss 0.013999968 Test MSE 0 Test RE 0
# 151 Train Loss 0.013879436 Test MSE 0 Test RE 0
# 152 Train Loss 0.013799092 Test MSE 0 Test RE 0
# 153 Train Loss 0.013718398 Test MSE 0 Test RE 0
# 154 Train Loss 0.013621732 Test MSE 0 Test RE 0
# 155 Train Loss 0.013441832 Test MSE 0 Test RE 0
# 156 Train Loss 0.01320156 Test MSE 0 Test RE 0
# 157 Train Loss 0.01288396 Test MSE 0 Test RE 0
# 158 Train Loss 0.012726925 Test MSE 0 Test RE 0
# 159 Train Loss 0.012665688 Test MSE 0 Test RE 0
# 160 Train Loss 0.012554898 Test MSE 0 Test RE 0
# 161 Train Loss 0.012473826 Test MSE 0 Test RE 0
# 162 Train Loss 0.012402744 Test MSE 0 Test RE 0
# 163 Train Loss 0.012322516 Test MSE 0 Test RE 0
# 164 Train Loss 0.012201082 Test MSE 0 Test RE 0
# 165 Train Loss 0.011966211 Test MSE 0 Test RE 0
# 166 Train Loss 0.011778038 Test MSE 0 Test RE 0
# 167 Train Loss 0.011609949 Test MSE 0 Test RE 0
# 168 Train Loss 0.011488194 Test MSE 0 Test RE 0
# 169 Train Loss 0.011398254 Test MSE 0 Test RE 0
# 170 Train Loss 0.011293236 Test MSE 0 Test RE 0
# 171 Train Loss 0.010998072 Test MSE 0 Test RE 0
# 172 Train Loss 0.010907769 Test MSE 0 Test RE 0
# 173 Train Loss 0.010851474 Test MSE 0 Test RE 0
# 174 Train Loss 0.0107719805 Test MSE 0 Test RE 0
# 175 Train Loss 0.010700237 Test MSE 0 Test RE 0
# 176 Train Loss 0.010604497 Test MSE 0 Test RE 0
# 177 Train Loss 0.010457848 Test MSE 0 Test RE 0
# 178 Train Loss 0.0103472015 Test MSE 0 Test RE 0
# 179 Train Loss 0.010086932 Test MSE 0 Test RE 0
# 180 Train Loss 0.009709433 Test MSE 0 Test RE 0
# 181 Train Loss 0.009552437 Test MSE 0 Test RE 0
# 182 Train Loss 0.009476797 Test MSE 0 Test RE 0
# 183 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 184 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 185 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 186 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 187 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 188 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 189 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 190 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 191 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 192 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 193 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 194 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 195 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 196 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 197 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 198 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 199 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 200 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 201 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 202 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 203 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 204 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 205 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 206 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 207 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 208 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 209 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 210 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 211 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 212 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 213 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 214 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 215 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 216 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 217 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 218 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 219 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 220 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 221 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 222 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 223 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 224 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 225 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 226 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 227 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 228 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 229 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 230 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 231 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 232 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 233 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 234 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 235 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 236 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 237 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 238 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 239 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 240 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 241 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 242 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 243 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 244 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 245 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 246 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 247 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 248 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 249 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 250 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 251 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 252 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 253 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 254 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 255 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 256 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 257 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 258 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 259 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 260 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 261 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 262 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 263 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 264 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 265 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 266 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 267 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 268 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 269 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 270 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 271 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 272 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 273 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 274 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 275 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 276 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 277 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 278 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 279 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 280 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 281 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 282 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 283 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 284 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 285 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 286 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 287 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 288 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 289 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 290 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 291 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 292 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 293 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 294 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 295 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 296 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 297 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 298 Train Loss 0.009446202 Test MSE 0 Test RE 0
# 299 Train Loss 0.009446202 Test MSE 0 Test RE 0
# Training time: 189.55
# Training time: 189.55

# %%
x = 0.0
y = np.linspace(0.1,10,500).reshape(-1,1)

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_test = PINN.forward(xy_test_tensor).cpu().detach().numpy()

a = k/(rho*c_p)
u_true_test = T0+1/(rho*c_p*np.sqrt(4*pi*a*y))

fig,ax = plt.subplots()
ax.plot(y,u_pred_test,'b--',label = 'pred')
ax.plot(y,u_true_test,'b',label = 'True')
ax.legend()

# %%
x = np.linspace(-0.2,0.2,500).reshape(-1,1)
# y = np.linspace(0,1,500).reshape(-1,1)
y = 0.1

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_t1 = PINN.forward(xy_test_tensor).cpu().detach().numpy()

a = k/(rho*c_p)
u_true_t1 = T0+ np.exp(-1*np.square(x)/(4*a*y))/(rho*c_p*np.sqrt(4*pi*a*y))

# %%
x = np.linspace(-0.2,0.2,500).reshape(-1,1)
# y = np.linspace(0,1,500).reshape(-1,1)
y = 1.0

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_t2 = PINN.forward(xy_test_tensor).cpu().detach().numpy()
u_true_t2 = T0+ np.exp(-1*np.square(x)/(4*a*y))/(rho*c_p*np.sqrt(4*pi*a*y))

# %%
x = np.linspace(-0.2,0.2,500).reshape(-1,1)
# y = np.linspace(0,1,500).reshape(-1,1)
y = 5

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_t3 = PINN.forward(xy_test_tensor).cpu().detach().numpy()
u_true_t3 = T0+ np.exp(-1*np.square(x)/(4*a*y))/(rho*c_p*np.sqrt(4*pi*a*y))

# %%
fig,ax = plt.subplots()
ax.plot(x,u_pred_t1,'b--',label = '0.1s')
# ax.plot(x,u_true_t1,'b')
ax.plot(x,u_pred_t2,'r--',label = '1s')
# ax.plot(x,u_true_t2,'r')
ax.plot(x,u_pred_t3,'k--',label = '5s')
# ax.plot(x,u_true_t3,'k')
ax.legend()
ax.set_xlabel('$x$',math_fontfamily = 'cm',fontsize = 14)
ax.set_ylabel('Temperature ($K$)',math_fontfamily = 'cm',fontsize = 14)
ax.set_title('Instantaneous Heat Source on a Rod',math_fontfamily = 'cm',fontsize = 16)
plt.save
# Out:
# Text(0.5, 1.0, 'Instantaneous Heat Source on a Rod')

# %%
np.max(u_pred_t3)/np.max(u_true_t3)
# Out:
# 1.0540211812578748

# %%
fig, ax = plt.subplots(1,1)
cmap = plt.cm.jet

img3 = ax.imshow(np.flip(u_pred.reshape(500,500),axis = 0),cmap = cmap,extent=[0,1,0,1],aspect = 0.75)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15161/871831276.py in <module>
#       2 cmap = plt.cm.jet
#       3
# ----> 4 img3 = ax.imshow(np.flip(u_pred.reshape(500,500),axis = 0),cmap = cmap,extent=[0,1,0,1],aspect = 0.75)
#
# ValueError: cannot reshape array of size 500 into shape (500,500)
