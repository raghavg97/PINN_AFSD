# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter
import matplotlib as mpl

import numpy as np
import time
from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:0

# %%
loss_thresh = 25000
level = "_low"
label = "Burgers_stan" + level

T0 = 300
pi = 3.14
rho = 1
c_p = 1
k = 0.001

x = np.linspace(-1,1,500).reshape(-1,1)
t = np.linspace(0,10,500).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

# bound_pts_1 = (X == 0).reshape(-1,)
# bound_pts_2 = np.logical_and(Y == 0,X != 0).reshape(-1,)
# bound_pts_3 = np.logical_and(X == 1,Y != 0).reshape(-1,) 
# bound_pts_4 = np.logical_and(Y == 1,X != 1).reshape(-1,) 

# xy_bound_1 = xy[bound_pts_1,:]
# xy_bound_2 = xy[bound_pts_2,:]
# xy_bound_3 = xy[bound_pts_3,:]
# xy_bound_4 = xy[bound_pts_4,:]

# u_bound_1 = 1000*np.ones((np.shape(xy_bound_1)[0],1))
# u_bound_2 = 800*np.ones((np.shape(xy_bound_2)[0],1))
# u_bound_3 = 500*np.ones((np.shape(xy_bound_3)[0],1))
# u_bound_4 = np.zeros((np.shape(xy_bound_4)[0],1))

# xy_bound = np.vstack((xy_bound_1,xy_bound_2,xy_bound_3,xy_bound_4))
# u_bound = np.vstack((u_bound_1,u_bound_2,u_bound_3,u_bound_4))

# xy_test_tensor = torch.from_numpy(xy).float().to(device)

lb_xt = xt[0]
ub_xt = xt[-1]

# %%
# data = scipy.io.loadmat('burgers_shock.mat') 

# pi = torch.from_numpy(np.array(np.pi)).double().to(device)

# x = np.array(data['x'])
# t = np.array(data['t'])

# X,T = np.meshgrid(x,t)

# X = X.flatten('F').reshape(-1,1)
# T = T.flatten('F').reshape(-1,1)
  
# xt = np.hstack((X,T))

# u_true = np.array(data['usol'][:])

# xt_test_tensor = torch.from_numpy(xt).float().to(device)
# u_true_norm = np.linalg.norm(u_true,2)

# %%
def trainingdata(N_T,N_f,seed):
    '''Boundary Conditions''' 
    
    np.random.seed(seed)
    
    x_l = x[0]*np.ones((N_T,1))
    t_l = np.random.uniform(t[0],t[-1],(N_T,1))
    xt_l = np.hstack((x_l,t_l))
    u_l = T0*np.ones((N_T,1))
    
    x_r = x[-1]*np.ones((N_T,1))
    t_r = np.random.uniform(t[0],t[-1],(N_T,1))
    xt_r = np.hstack((x_r,t_r))
    u_r = T0*np.ones((N_T,1))
    
    x_0 = np.random.uniform(x[0],x[-1],(N_T,1))
    t_0 = t[0]*np.ones((N_T,1))
    xt_0 = np.hstack((x_0,t_0))
    u_0 = T0*np.ones((N_T,1))
    
    xt_BC = np.vstack((xt_l,xt_r,xt_0)) #choose indices from  set 'idx' (x,t)
    u_BC = np.vstack((u_l,u_r,u_0))
    
    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    x01 = np.array([[0.0,1.0],[0.0,1.0]])
    sampling = LHS(xlimits=x01,random_state =seed)
    samples = sampling(N_f)
    
    xt_coll = lb_xt + (ub_xt - lb_xt)*samples
    
    #Additional Collocation 
    # x_c_coll = np.random.normal(0,0.05,(N_T,1))
    # t_c_coll = np.abs(np.random.normal(0,0.05,(N_T,1)))
    # xt_c_coll = np.hstack((x_c_coll,t_c_coll))
    
    
    xt_coll = np.vstack((xt_coll, xt_BC)) # append training points to collocation points 

    return xt_coll, xt_BC, u_BC

# %%
class Sequentialmodel(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

     
        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        self.iter = 0
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)   
        
        beta_mean = 1.0*torch.ones((50,len(layers)-2))
        beta_std = 0.1*torch.ones((50,len(layers)-2))
        
        self.beta = Parameter(torch.normal(beta_mean,beta_std))
        self.beta.requiresGrad = True
            
    'foward pass'
    def forward(self,xy):
        if torch.is_tensor(xy) != True:         
            xy = torch.from_numpy(xy)                
        
        ubxy = torch.from_numpy(ub_xt).float().to(device)
        lbxy = torch.from_numpy(lb_xt).float().to(device)
    
                      
        #preprocessing input 
        xy = 2.0*(xy - lbxy)/(ubxy - lbxy) - 1.0
        
        #convert to float
        a = xy.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            z1 =self.activation(z)
            a = z1 + self.beta[:,i]*z*z1
       
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xy,u):
                
        loss_bc = self.loss_function(self.forward(xy), u)
                
        return loss_bc
    
    
    def loss_heat(self, xy_coll,f_hat):
        g = xy_coll.clone()             
        g.requires_grad = True
        u = self.forward(g) 
        
        u_x_y = autograd.grad(u,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        


        du_dx = u_x_y[:,[0]]
        
        #Heat source Gaussian Distributed in x and t
        sigma_x = 0.02
        sigma_t = 0.1
        exp_term1 = torch.square(g[:,0].reshape(-1,1))/sigma_x**2
        exp_term2 =  torch.square(g[:,1].reshape(-1,1))/sigma_t**2
        
        Q = torch.exp(-0.5*(exp_term1 + exp_term2))/(np.sqrt(2*pi*sigma_x*sigma_t)) 
        
        f = k*du_dx - Q
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
        
    
    def loss_PDE(self, xy_coll, f_hat):
        
        g = xy_coll.clone()             
        g.requires_grad = True
        u = self.forward(g) 
        
        u_x_y = autograd.grad(u,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        u_xx_yy = autograd.grad(u_x_y,g,torch.ones(xy_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        du_dx = u_x_y[:,[0]]
        du_dt = u_x_y[:,[1]]
        
        d2u_dx2 = u_xx_yy[:,[0]]
        
        #Heat source Gaussian Distributed in x and t
        # sigma_x = 0.02
        # sigma_t = 0.1
        # exp_term1 = torch.square(g[:,0].reshape(-1,1))/sigma_x**2
        # exp_term2 =  torch.square(g[:,1].reshape(-1,1))/sigma_t**2
        
        # Q = 100.0*torch.exp(-0.5*(exp_term1 + exp_term2))/(np.sqrt(2*pi*sigma_x*sigma_t)) 
        
        f = rho*c_p*du_dt - k*d2u_dx2 #- Q
        
        loss_f = self.loss_function(f,f_hat)
                
        return loss_f
    
    def loss(self,xy_BC,u_BC,xy_coll,f_hat):

        loss_BC = self.loss_BC(xy_BC,u_BC)
        loss_f = self.loss_PDE(xy_coll,f_hat)
        loss_heat = self.loss_heat(xy_coll,f_hat)
        
        loss_val = loss_BC + loss_f + loss_heat
        
        return loss_val
         
    'test neural network'
    def test(self):
        # u_pred = self.forward(xt_test_tensor)
        # u_pred = u_pred.cpu().detach().numpy()
        u_pred = 0
   
        return u_pred

    def test_loss(self):
        u_pred = self.test()
        
        # test_mse = np.mean(np.square(u_pred.reshape(-1,1) - u_true.reshape(-1,1)))
        # test_re = np.linalg.norm(u_pred.reshape(-1,1) - u_true.reshape(-1,1),2)/u_true_norm
        test_mse = 0
        test_re = 0
        
        return test_mse, test_re

# %%
def data_update(loss_np):
    train_loss.append(loss_np)

    
    test_mse, test_re = PINN.test_loss()
    test_mse_loss.append(test_mse)
    test_re_loss.append(test_re)

# %%
def train_step(xy_BC,u_BC,xy_coll,f_hat,seed):

    def closure():
        optimizer.zero_grad()
        loss = PINN.loss(xy_BC,u_BC,xy_coll,f_hat)
        loss.backward()
        #print(loss.cpu().detach().numpy())
        return loss

    optimizer.step(closure)

# %%
def train_model(max_iter,rep): 
    print(rep) 
    torch.manual_seed(rep*9)
    start_time = time.time() 
    thresh_flag = 0

    xy_coll_np_array, xy_BC_np_array, u_BC_np_array = trainingdata(N_T,N_f,rep*22)
        
    xy_coll = torch.from_numpy(xy_coll_np_array).float().to(device)
    xy_BC = torch.from_numpy(xy_BC_np_array).float().to(device)
    u_BC = torch.from_numpy(u_BC_np_array).float().to(device)
        
    f_hat = torch.zeros(xy_coll.shape[0],1).to(device)
    

    for i in range(max_iter):
        train_step(xy_BC,u_BC,xy_coll,f_hat,i)
        loss_np = PINN.loss(xy_BC,u_BC,xy_coll,f_hat).cpu().detach().numpy()
        
        if(thresh_flag == 0):
            if(loss_np < loss_thresh):
                time_threshold[rep] = time.time() - start_time
                epoch_threshold[rep] = i+1          
                thresh_flag = 1       
        data_update(loss_np)
        
        print(i,"Train Loss",train_loss[-1],"Test MSE",test_mse_loss[-1],"Test RE",test_re_loss[-1])   
        
    elapsed_time[rep] = time.time() - start_time  
    print('Training time: %.2f' % (elapsed_time[rep]))

# %%
max_reps = 1
max_iter = 300 #200

train_loss_full = []
test_mse_full = []
test_re_full = []

elapsed_time= np.zeros((max_reps,1))
time_threshold = np.empty((max_reps,1))
time_threshold[:] = np.nan
epoch_threshold = max_iter*np.ones((max_reps,1))



N_T = 500 #Total number of data points for 'y'
N_f = 10000 #Total number of collocation points 


for reps in range(max_reps):
    print(label)
    print(reps)
    train_loss = []
    test_mse_loss = []
    test_re_loss = []
 
    
    torch.manual_seed(reps*36)
    
    layers = np.array([2,50,50,50,50,50,1]) #9 hidden layers

    PINN = Sequentialmodel(layers)
   
    PINN.to(device)

    'Neural Network Summary'
    print(PINN)

    params = list(PINN.parameters())
    
    optimizer = torch.optim.LBFGS(PINN.parameters(), lr=1, 
                              max_iter = 20, 
                              max_eval = 30, 
                              tolerance_grad = 1e-08, 
                              tolerance_change = 1e-08, 
                              history_size = 100, 
                              line_search_fn = 'strong_wolfe')



   
    
    nan_flag = train_model(max_iter,reps)
    
    
    torch.save(PINN.state_dict(),label+'_'+str(reps)+'.pt')
    train_loss_full.append(train_loss)
    test_mse_full.append(test_mse_loss)
    test_re_full.append(test_re_loss)
    #elapsed_time[reps] = time.time() - start_time



    print('Training time: %.2f' % (elapsed_time[reps]))
    
mdic = {"train_loss": train_loss_full,"test_mse_loss": test_mse_full,"test_re_loss": test_re_full,"Time": elapsed_time, "label": label,"Thresh Time": time_threshold,"Thresh epoch": epoch_threshold}
savemat(label+'.mat', mdic)
# Out:
# Burgers_stan_low
# 0
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# 0
# 0 Train Loss 48.540897 Test MSE 0 Test RE 0
# 1 Train Loss 2.344077 Test MSE 0 Test RE 0
# 2 Train Loss 0.46497092 Test MSE 0 Test RE 0
# 3 Train Loss 0.12665385 Test MSE 0 Test RE 0
# 4 Train Loss 0.087982476 Test MSE 0 Test RE 0
# 5 Train Loss 0.071253195 Test MSE 0 Test RE 0
# 6 Train Loss 0.058999952 Test MSE 0 Test RE 0
# 7 Train Loss 0.055897098 Test MSE 0 Test RE 0
# 8 Train Loss 0.053354576 Test MSE 0 Test RE 0
# 9 Train Loss 0.05260724 Test MSE 0 Test RE 0
# 10 Train Loss 0.052071303 Test MSE 0 Test RE 0
# 11 Train Loss 0.051971257 Test MSE 0 Test RE 0
# 12 Train Loss 0.051814765 Test MSE 0 Test RE 0
# 13 Train Loss 0.05171601 Test MSE 0 Test RE 0
# 14 Train Loss 0.05157511 Test MSE 0 Test RE 0
# 15 Train Loss 0.051347278 Test MSE 0 Test RE 0
# 16 Train Loss 0.051281057 Test MSE 0 Test RE 0
# 17 Train Loss 0.051129356 Test MSE 0 Test RE 0
# 18 Train Loss 0.05109375 Test MSE 0 Test RE 0
# 19 Train Loss 0.051052097 Test MSE 0 Test RE 0
# 20 Train Loss 0.05102974 Test MSE 0 Test RE 0
# 21 Train Loss 0.051006086 Test MSE 0 Test RE 0
# 22 Train Loss 0.050958358 Test MSE 0 Test RE 0
# 23 Train Loss 0.050910957 Test MSE 0 Test RE 0
# 24 Train Loss 0.05089795 Test MSE 0 Test RE 0
# 25 Train Loss 0.050883453 Test MSE 0 Test RE 0
# 26 Train Loss 0.05087321 Test MSE 0 Test RE 0
# 27 Train Loss 0.050872225 Test MSE 0 Test RE 0
# 28 Train Loss 0.050869726 Test MSE 0 Test RE 0
# 29 Train Loss 0.050864976 Test MSE 0 Test RE 0
# 30 Train Loss 0.05086384 Test MSE 0 Test RE 0
# 31 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 32 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 33 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 34 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 35 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 36 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 37 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 38 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 39 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 40 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 41 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 42 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 43 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 44 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 45 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 46 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 47 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 48 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 49 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 50 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 51 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 52 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 53 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 54 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 55 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 56 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 57 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 58 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 59 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 60 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 61 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 62 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 63 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 64 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 65 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 66 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 67 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 68 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 69 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 70 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 71 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 72 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 73 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 74 Train Loss 0.050863814 Test MSE 0 Test RE 0
# 75 Train Loss 0.050863814 Test MSE 0 Test RE 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32616/3616024973.py in <module>
#      50
#      51
# ---> 52     nan_flag = train_model(max_iter,reps)
#      53
#      54
#
# /tmp/ipykernel_32616/1919774869.py in train_model(max_iter, rep)
#      15
#      16     for i in range(max_iter):
# ---> 17         train_step(xy_BC,u_BC,xy_coll,f_hat,i)
#      18         loss_np = PINN.loss(xy_BC,u_BC,xy_coll,f_hat).cpu().detach().numpy()
#      19
#
# /tmp/ipykernel_32616/896708044.py in train_step(xy_BC, u_BC, xy_coll, f_hat, seed)
#       8         return loss
#       9
# ---> 10     optimizer.step(closure)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     386                 d = r = torch.mul(q, H_diag)
#     387                 for i in range(num_old):
# --> 388                     be_i = old_dirs[i].dot(r) * ro[i]
#     389                     r.add_(old_stps[i], alpha=al[i] - be_i)
#     390
#
# KeyboardInterrupt:

# %%
x = np.linspace(-0.2,0.2,500).reshape(-1,1)
# y = np.linspace(0,1,500).reshape(-1,1)
y = 0.1

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_t1 = PINN.forward(xy_test_tensor).cpu().detach().numpy()

a = k/(rho*c_p)
u_true_t1 = T0+ np.exp(-1*np.square(x)/(4*a*y))/(rho*c_p*np.sqrt(4*pi*a*y))

# %%
x = np.linspace(-0.2,0.2,500).reshape(-1,1)
# y = np.linspace(0,1,500).reshape(-1,1)
y = 1.0

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_t2 = PINN.forward(xy_test_tensor).cpu().detach().numpy()
u_true_t2 = T0+ np.exp(-1*np.square(x)/(4*a*y))/(rho*c_p*np.sqrt(4*pi*a*y))

# %%
x = np.linspace(-0.2,0.2,500).reshape(-1,1)
# y = np.linspace(0,1,500).reshape(-1,1)
y = 5

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

u_pred_t3 = PINN.forward(xy_test_tensor).cpu().detach().numpy()
u_true_t3 = T0+ np.exp(-1*np.square(x)/(4*a*y))/(rho*c_p*np.sqrt(4*pi*a*y))

# %%
fig,ax = plt.subplots()
ax.plot(x,u_pred_t1,'b--',label = '0.1s')
# ax.plot(x,u_true_t1,'b')
ax.plot(x,u_pred_t2,'r--',label = '1s')
# ax.plot(x,u_true_t2,'r')
ax.plot(x,u_pred_t3,'k--',label = '5s')
# ax.plot(x,u_true_t3,'k')
ax.legend()
ax.set_xlabel('$x$',math_fontfamily = 'cm',fontsize = 14)
ax.set_ylabel('Temperature ($K$)',math_fontfamily = 'cm',fontsize = 14)
ax.set_title('Instantaneous Heat Source on a Rod',math_fontfamily = 'cm',fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Instantaneous Heat Source on a Rod')

# %%
fig, ax = plt.subplots(1,1)
cmap = plt.cm.jet

img3 = ax.imshow(np.flip(u_pred.reshape(500,500),axis = 0),cmap = cmap,extent=[0,1,0,1],aspect = 0.75)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15161/871831276.py in <module>
#       2 cmap = plt.cm.jet
#       3
# ----> 4 img3 = ax.imshow(np.flip(u_pred.reshape(500,500),axis = 0),cmap = cmap,extent=[0,1,0,1],aspect = 0.75)
#
# ValueError: cannot reshape array of size 500 into shape (500,500)
