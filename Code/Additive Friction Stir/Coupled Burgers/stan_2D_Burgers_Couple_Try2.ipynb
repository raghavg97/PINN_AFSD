# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter
import matplotlib as mpl

import numpy as np
import time
from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:0

# %%
loss_thresh = 25000
level = "_low"
label = "Burgers_stan" + level

x = np.linspace(-1,1,256).reshape(-1,1)
t = np.linspace(0,1,100).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

# bound_pts_1 = (X == 0).reshape(-1,)
# bound_pts_2 = np.logical_and(Y == 0,X != 0).reshape(-1,)
# bound_pts_3 = np.logical_and(X == 1,Y != 0).reshape(-1,) 
# bound_pts_4 = np.logical_and(Y == 1,X != 1).reshape(-1,) 

# xy_bound_1 = xy[bound_pts_1,:]
# xy_bound_2 = xy[bound_pts_2,:]
# xy_bound_3 = xy[bound_pts_3,:]
# xy_bound_4 = xy[bound_pts_4,:]

# u_bound_1 = 1000*np.ones((np.shape(xy_bound_1)[0],1))
# u_bound_2 = 800*np.ones((np.shape(xy_bound_2)[0],1))
# u_bound_3 = 500*np.ones((np.shape(xy_bound_3)[0],1))
# u_bound_4 = np.zeros((np.shape(xy_bound_4)[0],1))

# xy_bound = np.vstack((xy_bound_1,xy_bound_2,xy_bound_3,xy_bound_4))
# u_bound = np.vstack((u_bound_1,u_bound_2,u_bound_3,u_bound_4))

# xy_test_tensor = torch.from_numpy(xy).float().to(device)

lb_xt = xt[0]
ub_xt = xt[-1]

# %%
pi = torch.from_numpy(np.array(np.pi)).double().to(device)


x = np.linspace(-1,1,256)
t = np.linspace(0,1,100)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

xt_test_tensor = torch.from_numpy(xt).float().to(device)

# %%
data = scipy.io.loadmat('Burgers_simplified_coupled_T2.mat') 
uT_true = np.array(data['sol'])
u_true = np.transpose(uT_true[:,:,0])
T_true = np.transpose(uT_true[:,:,1])


u_true_norm = np.linalg.norm(u_true,2)
T_true_norm = np.linalg.norm(T_true,2)

# %%
plt.imshow(u_true)

# %%
def trainingdata(N_T,N_f,seed):
    '''Boundary Conditions''' 
    
    np.random.seed(seed)
    
    x_l = x[0]*np.ones((N_T,1))
    t_l = np.random.uniform(t[0],t[-1],(N_T,1))
    xt_l = np.hstack((x_l,t_l))
    u_l = 0.0*np.ones((N_T,1))
    T_l = 100.0*np.ones((N_T,1))
    
    x_r = x[-1]*np.ones((N_T,1))
    t_r = np.random.uniform(t[0],t[-1],(N_T,1))
    xt_r = np.hstack((x_r,t_r))
    u_r = 0.0*np.ones((N_T,1))
    T_r = 100.0*np.ones((N_T,1))
    
    
    x_0 = np.random.uniform(x[0],x[-1],(N_T,1))
    t_0 = t[0]*np.ones((N_T,1))
    xt_0 = np.hstack((x_0,t_0))
    u_0 = -1.0*np.sin(np.pi*x_0)
    T_0 = 100.0*np.ones((N_T,1))
    
    xt_BC = np.vstack((xt_l,xt_r,xt_0)) #choose indices from  set 'idx' (x,t)
    u_BC = np.vstack((u_l,u_r,u_0))
    T_BC = np.vstack((T_l,T_r,T_0))
    
    uT_BC = np.hstack((u_BC,T_BC))
    
    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    x01 = np.array([[0.0,1.0],[0.0,1.0]])
    sampling = LHS(xlimits=x01,random_state =seed)
    samples = sampling(N_f)
    
    xt_coll = lb_xt + (ub_xt - lb_xt)*samples
    
    xt_coll = np.vstack((xt_coll, xt_BC)) # append training points to collocation points 

    return xt_coll, xt_BC, uT_BC

# %%
class Sequentialmodel(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

     
        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        self.iter = 0
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)   
        
        beta_mean = 1.0*torch.ones((50,len(layers)-2))
        beta_std = 0.1*torch.ones((50,len(layers)-2))
        
        self.beta = Parameter(torch.normal(beta_mean,beta_std))
        self.beta.requiresGrad = True
            
    'foward pass'
    def forward(self,xy):
        if torch.is_tensor(xy) != True:         
            xy = torch.from_numpy(xy)                
        
        ubxy = torch.from_numpy(ub_xt).float().to(device)
        lbxy = torch.from_numpy(lb_xt).float().to(device)
    
                      
        #preprocessing input 
        xy = 2.0*(xy - lbxy)/(ubxy - lbxy) - 1.0
        
        #convert to float
        a = xy.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            z1 =self.activation(z)
            a = z1 + self.beta[:,i]*z*z1
       
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xy,uT):
        
        uT_pred = self.forward(xy)
        u_pred = uT_pred[:,0]
        T_pred = uT_pred[:,1]
        
        loss_bc_u = self.loss_function(u_pred, uT[:,0])
        loss_bc_T = self.loss_function(T_pred, uT[:,1])
                
        # return loss_bc_u + loss_bc_T
        return loss_bc_T
    
    def loss_PDE(self, xy_coll, f_hat):
        
        g = xy_coll.clone()             
        g.requires_grad = True
        uT = self.forward(g) 
        
        u = uT[:,0:1]
        T = uT[:,1:2]
        
        u_x_y = autograd.grad(u,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        u_xx_yy = autograd.grad(u_x_y,g,torch.ones(xy_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        du_dx = u_x_y[:,[0]]
        du_dt = u_x_y[:,[1]]
        d2u_dx2 = u_xx_yy[:,[0]]
        
        T_x_y = autograd.grad(T,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        T_xx_yy = autograd.grad(T_x_y,g,torch.ones(xy_coll.shape).to(device), create_graph=True,allow_unused = True)[0]
        
        dT_dx = T_x_y[:,[0]]
        dT_dt = T_x_y[:,[1]]
        d2T_dx2 = T_xx_yy[:,[0]]
        
        f1 = du_dt + u*du_dx - 0.1*d2u_dx2/pi
        
        # u = u.detach()
        
        u_times_T = u*T
        u_times_T_x_y = autograd.grad(u_times_T,g,torch.ones([xy_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]

        duT_dx = u_times_T_x_y[:,[0]]
        
        alpha = 1
        
        
        f2 = dT_dt - alpha*d2T_dx2 + duT_dx
        
        loss_f1 = self.loss_function(f1,f_hat)
        loss_f2 = self.loss_function(f2,f_hat)
                
        # return loss_f1 + loss_f2
        return loss_f2
    
    def loss(self,xy_BC,uT_BC,xy_coll,f_hat):

        loss_BC = self.loss_BC(xy_BC,uT_BC)
        loss_f = self.loss_PDE(xy_coll,f_hat)
        
        loss_val = loss_BC + loss_f
        
        return loss_val
         
    'test neural network'
    def test(self):
        uT_pred = self.forward(xt_test_tensor)
   
        return uT_pred.cpu().detach().numpy()

    def test_loss(self):
        uT_pred = self.test()
        u_pred = uT_pred[:,0]
        T_pred = uT_pred[:,1]
        
        # test_mse = np.mean(np.square(u_pred.reshape(-1,1) - u_true.reshape(-1,1)))
        test_re_u = np.linalg.norm(u_pred.reshape(-1,1) - u_true.reshape(-1,1),2)/u_true_norm
        test_re_T = np.linalg.norm(T_pred.reshape(-1,1) - T_true.reshape(-1,1),2)/T_true_norm
        
        
        return test_re_u, test_re_T

# %%
def data_update(loss_np):
    train_loss.append(loss_np)

    
    test_mse, test_re = PINN.test_loss()
    test_mse_loss.append(test_mse)
    test_re_loss.append(test_re)

# %%
def train_step(xy_BC,uT_BC,xy_coll,f_hat,seed):

    def closure():
        optimizer.zero_grad()
        loss = PINN.loss(xy_BC,uT_BC,xy_coll,f_hat)
        loss.backward()
        #print(loss.cpu().detach().numpy())
        return loss

    optimizer.step(closure)

# %%
def train_model(max_iter,rep): 
    print(rep) 
    torch.manual_seed(rep*9)
    start_time = time.time() 
    thresh_flag = 0

    xy_coll_np_array, xy_BC_np_array, uT_BC_np_array = trainingdata(N_T,N_f,rep*22)
        
    xy_coll = torch.from_numpy(xy_coll_np_array).float().to(device)
    xy_BC = torch.from_numpy(xy_BC_np_array).float().to(device)
    uT_BC = torch.from_numpy(uT_BC_np_array).float().to(device)
        
    f_hat = torch.zeros(xy_coll.shape[0],1).to(device)
    

    for i in range(max_iter):
        train_step(xy_BC,uT_BC,xy_coll,f_hat,i)
        loss_np = PINN.loss(xy_BC,uT_BC,xy_coll,f_hat).cpu().detach().numpy()
        
        if(thresh_flag == 0):
            if(loss_np < loss_thresh):
                time_threshold[rep] = time.time() - start_time
                epoch_threshold[rep] = i+1          
                thresh_flag = 1       
        data_update(loss_np)
        
        print(i,"Train Loss",train_loss[-1],"RE u:",test_mse_loss[-1],"RE T:",test_re_loss[-1])   
        
    elapsed_time[rep] = time.time() - start_time  
    print('Training time: %.2f' % (elapsed_time[rep]))

# %%
max_reps = 1
max_iter = 500 #200

train_loss_full = []
test_mse_full = []
test_re_full = []

elapsed_time= np.zeros((max_reps,1))
time_threshold = np.empty((max_reps,1))
time_threshold[:] = np.nan
epoch_threshold = max_iter*np.ones((max_reps,1))



N_T = 500 #Total number of data points for 'y'
N_f = 10000 #Total number of collocation points 


for reps in range(max_reps):
    print(label)
    print(reps)
    train_loss = []
    test_mse_loss = []
    test_re_loss = []
 
    
    torch.manual_seed(reps*36)
    
    layers = np.array([2,50,50,50,50,50,2]) #9 hidden layers

    PINN = Sequentialmodel(layers)
   
    PINN.to(device)

    'Neural Network Summary'
    print(PINN)

    params = list(PINN.parameters())
    
    optimizer = torch.optim.LBFGS(PINN.parameters(), lr=1, 
                              max_iter = 20, 
                              max_eval = 30, 
                              tolerance_grad = 1e-08, 
                              tolerance_change = 1e-08, 
                              history_size = 100, 
                              line_search_fn = 'strong_wolfe')



   
    
    nan_flag = train_model(max_iter,reps)
    
    
    torch.save(PINN.state_dict(),label+'_'+str(reps)+'.pt')
    train_loss_full.append(train_loss)
    test_mse_full.append(test_mse_loss)
    test_re_full.append(test_re_loss)
    #elapsed_time[reps] = time.time() - start_time



    print('Training time: %.2f' % (elapsed_time[reps]))
    
mdic = {"train_loss": train_loss_full,"test_mse_loss": test_mse_full,"test_re_loss": test_re_full,"Time": elapsed_time, "label": label,"Thresh Time": time_threshold,"Thresh epoch": epoch_threshold}
savemat(label+'.mat', mdic)
# Out:
# Burgers_stan_low
# 0
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): Linear(in_features=50, out_features=2, bias=True)
#   )
# )
# 0
# 0 Train Loss 133.66553 RE u: 4.955555039947393 RE T: 0.24576455604578995
# 1 Train Loss 4.2823544 RE u: 4.761214848190031 RE T: 0.21898050540951405
# 2 Train Loss 0.72065187 RE u: 4.394650851162659 RE T: 0.21091295317573006
# 3 Train Loss 0.23778692 RE u: 4.120260074639898 RE T: 0.20545248406558855
# 4 Train Loss 0.15030012 RE u: 3.985307187149681 RE T: 0.20290920332347304
# 5 Train Loss 0.076610364 RE u: 3.6311665632472487 RE T: 0.19908212930911168
# 6 Train Loss 0.039411675 RE u: 3.5687235052460187 RE T: 0.19750984471344368
# 7 Train Loss 0.021917704 RE u: 3.5417708298273 RE T: 0.19698955143007196
# 8 Train Loss 0.010770672 RE u: 3.6552022696093482 RE T: 0.196251107011269
# 41 Train Loss 5.6471683e-05 RE u: 2.1299002710695394 RE T: 0.19277803905573135
# 42 Train Loss 5.025835e-05 RE u: 2.0937764011187867 RE T: 0.19262671004760495
# 43 Train Loss 4.821118e-05 RE u: 2.0118596079728928 RE T: 0.19251518600320197
# 44 Train Loss 4.8098787e-05 RE u: 1.9984604937803074 RE T: 0.19252343896099444
# 45 Train Loss 4.6949513e-05 RE u: 1.9891934481692948 RE T: 0.1926301711081245
# 46 Train Loss 4.4055923e-05 RE u: 1.9492968941963602 RE T: 0.1927288438875505
# 47 Train Loss 4.2479798e-05 RE u: 1.950667087656538 RE T: 0.1927219831352721
# 48 Train Loss 4.2223204e-05 RE u: 1.9585837311948984 RE T: 0.19270037175474378
# 49 Train Loss 4.2200503e-05 RE u: 1.9594381021851608 RE T: 0.19269948125623446
# 50 Train Loss 4.218058e-05 RE u: 1.9615417147956689 RE T: 0.19269525737206863
# 51 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 52 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 53 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 54 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 55 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 56 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 57 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 58 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 59 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 60 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 61 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 62 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 63 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 64 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 65 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 66 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 67 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 68 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 69 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 70 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 71 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 72 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 73 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 74 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 75 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 76 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 77 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 78 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 79 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 80 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 81 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 82 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 83 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 84 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 85 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 86 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 87 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 88 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 89 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 90 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 91 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 92 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 93 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 94 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 95 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 96 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 97 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 98 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 99 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 100 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 101 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 102 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 103 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 104 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 105 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 106 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 107 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 108 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 109 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 110 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 111 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 112 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# 113 Train Loss 4.2026775e-05 RE u: 1.9866578147852625 RE T: 0.1926995105860162
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12042/1786993094.py in <module>
#      50
#      51
# ---> 52     nan_flag = train_model(max_iter,reps)
#      53
#      54
#
# /tmp/ipykernel_12042/217698918.py in train_model(max_iter, rep)
#      16     for i in range(max_iter):
#      17         train_step(xy_BC,uT_BC,xy_coll,f_hat,i)
# ---> 18         loss_np = PINN.loss(xy_BC,uT_BC,xy_coll,f_hat).cpu().detach().numpy()
#      19
#      20         if(thresh_flag == 0):
#
# /tmp/ipykernel_12042/1676001426.py in loss(self, xy_BC, uT_BC, xy_coll, f_hat)
#     110
#     111         loss_BC = self.loss_BC(xy_BC,uT_BC)
# --> 112         loss_f = self.loss_PDE(xy_coll,f_hat)
#     113
#     114         loss_val = loss_BC + loss_f
#
# /tmp/ipykernel_12042/1676001426.py in loss_PDE(self, xy_coll, f_hat)
#      68         g = xy_coll.clone()
#      69         g.requires_grad = True
# ---> 70         uT = self.forward(g)
#      71
#      72         u = uT[:,0:1]
#
# /tmp/ipykernel_12042/1676001426.py in forward(self, xy)
#      32             xy = torch.from_numpy(xy)
#      33
# ---> 34         ubxy = torch.from_numpy(ub_xt).float().to(device)
#      35         lbxy = torch.from_numpy(lb_xt).float().to(device)
#      36
#
# KeyboardInterrupt:

# %%
x = np.linspace(-1,1,500).reshape(-1,1)
y = np.linspace(0,1,500).reshape(-1,1)

X,Y = np.meshgrid(x,y)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
  
xy = np.hstack((X,Y))

xy_test_tensor = torch.from_numpy(xy).float().to(device)

uT_pred = PINN.forward(xy_test_tensor).cpu().detach().numpy()
u_pred = uT_pred[:,0]
T_pred = uT_pred[:,1]

# %%
fig, ax = plt.subplots(1,1)
cmap = plt.cm.jet

img3 = ax.imshow(np.flip(u_pred.reshape(500,500),axis = 0),cmap = cmap,extent=[0,1,0,1],aspect = 0.75)

# %%
img3 = plt.imshow(np.flip(T_pred.reshape(500,500),axis = 0),cmap = cmap,extent=[0,1,0,1],aspect = 0.75)
