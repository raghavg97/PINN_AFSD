# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter

import numpy as np
import time
# from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io

from smt.sampling_methods import LHS
from scipy.io import savemat, loadmat

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:3

# %%
# def true_1D_1(x): #True function for 1D_1 dy2/dx2 + dy/dx - 6y = 0; BC1: y(0)=2; BC2: dy/dx at (x=0) = -1;
#     y = np.exp(-4.0*x) + np.exp(3.0*x)
#     return y

# %%
level = "high"
label = "Vpol_vPINN" 

#MATLAB Van Der Pol Example https://www.mathworks.com/help/matlab/ref/ode89.html
mu = 1
fo_val = 0.0

loss_thresh = 0.005

x = np.linspace(0,10,100).reshape(-1,1)

bc1_x = x[0].reshape(-1,1)
bc1_y = np.array([2]).reshape(-1,1)
x_bc1_train = torch.from_numpy(bc1_x).float().to(device)
y_bc1_train = torch.from_numpy(bc1_y).float().to(device)
    

bc2_x = x[0].reshape(-1,1)
x_bc2_train = torch.from_numpy(bc2_x).float().to(device)
bc2_val = torch.tensor(fo_val,device=device)
bc2_val = bc2_val.view(1,1)

x_test = x.reshape(-1,1)
x_test_tensor = torch.from_numpy(x_test).float().to(device)
# y_true = true_1D_1(x_test)
# y_true_norm = np.linalg.norm(y_true,2)

# Domain bounds
lb = np.array(x[0]) 
ub = np.array(x[-1])

# %%
def colloc_pts(N_f,seed):
    #Collocation Points
    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,y)
    x01 = np.array([[0.0, 1.0]])
    sampling = LHS(xlimits=x01,random_state =seed)
    
    x_coll_train = lb + (ub-lb)*sampling(N_f)
    x_coll_train = np.vstack((x_coll_train, bc1_x.reshape(-1,1))) # append training points to collocation points 

    return x_coll_train

# %%
class Sequentialmodel(nn.Module):
    
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class 
              
    
        self.activation = nn.Tanh()
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data) 
        
        self.beta = Parameter(torch.ones((100,len(layers)-2)))
        self.beta.requiresGrad = True
    
    'forward pass'
    def forward(self,x):
        if torch.is_tensor(x) != True:         
            x = torch.from_numpy(x)                
        
        u_b = torch.from_numpy(ub).float().to(device)
        l_b = torch.from_numpy(lb).float().to(device)
                      
        #preprocessing input 
        x = 2.0*(x - l_b)/(u_b - l_b) - 1.0 #feature scaling
        
        #convert to float
        a = x.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            a = self.activation(z) #+ self.beta[:,i]*z*self.activation(z)
            
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC1(self,x,y):
                
        loss_bc1 = self.loss_function(self.forward(x)[:,0:1], y)
                
        return loss_bc1
    
    def loss_BC2(self,x_bc2,bc2_val):
#         g = x_bc2.clone()             
#         g.requires_grad = True
#         y = self.forward(g)    
            
#         y_x = autograd.grad(y,g,torch.ones([x_bc2.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
#         dy_dx = y_x[:,[0]]
        
#         bc2 = dy_dx
        
        loss_bc2= self.loss_function(self.forward(x_bc2)[:,1:2],bc2_val)

        return loss_bc2
    
    def loss_PDE(self, x_coll,f_hat):
             
        g = x_coll.clone()             
        g.requires_grad = True
  
        y1 = self.forward(g)[:,0:1]
        y2 = self.forward(g)[:,1:2]

        y1_x = autograd.grad(y1,g,torch.ones([x_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        y2_x = autograd.grad(y2,g,torch.ones([x_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]

        dy1_dx = y1_x[:,[0]]
        dy2_dx = y2_x[:,[0]]
        
        f1 = dy1_dx - y2
        f2 = dy2_dx - mu*(1-torch.square(y1))*y2 + y1 
        
        # f = dy2_d2x + dy_dx - u_coeff*y
        # f = dy2_d2x - mu*(1-torch.square(y))*dy_dx + y 
        
        loss_f1 = self.loss_function(f1,f_hat)
        loss_f2 = self.loss_function(f2,f_hat)
                
        return loss_f1 + loss_f2
    
    
    def loss(self,x_bc1,y_bc1,x_bc2,bc2_val,x_coll,f_hat):

        loss_bc1 = self.loss_BC1(x_bc1,y_bc1)
        loss_bc2 = self.loss_BC2(x_bc2,bc2_val)
        loss_f = self.loss_PDE(x_coll,f_hat)
        
        loss_val = loss_bc1 + loss_bc2 + loss_f
        
        return loss_val
          
    'test neural network'
    
    def test(self):
        y_pred = self.forward(x_test_tensor)
        y_pred = y_pred.cpu().detach().numpy()

        return y_pred
    
    def test_loss(self):
        y_pred = self.test()
        
        # test_mse = np.mean(np.square(y_pred.reshape(-1,1) - y_true.reshape(-1,1)))
        # test_re = np.linalg.norm(y_pred.reshape(-1,1) - y_true.reshape(-1,1),2)/y_true_norm
        test_mse = 0
        test_re = 0
        
        return test_mse, test_re

# %%
def train_step(x_coll,f_hat):
    def closure():
        optimizer.zero_grad()
        loss = PINN.loss(x_bc1_train,y_bc1_train,x_bc2_train,bc2_val,x_coll,f_hat)
        loss.backward()
        
        return loss

    optimizer.step(closure)

# %%
def data_update(loss_np):
    train_loss.append(loss_np)
    beta_val.append(PINN.beta.cpu().detach().numpy())
    
    test_mse, test_re = PINN.test_loss()
    test_mse_loss.append(test_mse)
    test_re_loss.append(test_re)

# %%
def train_model(max_iter,rep):
    print(rep) 
    torch.manual_seed(rep*123)
    start_time = time.time()
    thresh_flag = 0
    
    x_coll = torch.from_numpy(colloc_pts(N_f,0)).float().to(device)
    f_hat = torch.zeros(x_coll.shape[0],1).to(device)
    
    loss_np = PINN.loss(x_bc1_train,y_bc1_train,x_bc2_train,bc2_val,x_coll,f_hat).cpu().detach().numpy()
    data_update(loss_np)
    for i in range(max_iter):
        x_coll = torch.from_numpy(colloc_pts(N_f,i*11)).float().to(device)
        f_hat = torch.zeros(x_coll.shape[0],1).to(device)
        train_step(x_coll,f_hat)
        
        loss_np = PINN.loss(x_bc1_train,y_bc1_train,x_bc2_train,bc2_val,x_coll,f_hat).cpu().detach().numpy()
        if(thresh_flag == 0):
            if(loss_np < loss_thresh):
                time_threshold[rep] = time.time() - start_time
                epoch_threshold[rep] = i+1            
                thresh_flag = 1       
        data_update(loss_np)
        print(i,"Train Loss",train_loss[-1],"Test MSE",test_mse_loss[-1],"Test RE",test_re_loss[-1])
    
    elapsed_time[rep] = time.time() - start_time
    print('Training time: %.2f' % (elapsed_time[rep]))

# %%
max_reps = 1
max_iter = 200

N_f = 1000

train_loss_full = []
test_mse_full = []
test_re_full = []
beta_full = []
elapsed_time= np.zeros((max_reps,1))

time_threshold = np.empty((max_reps,1))
time_threshold[:] = np.nan
epoch_threshold = max_iter*np.ones((max_reps,1))

for reps in range(max_reps):
    
    train_loss = []
    test_mse_loss = []
    test_re_loss =[]
    beta_val = []
    
    'Generate Training data'
    torch.manual_seed(reps*36)
     #Total number of collocation points 
    
    
    # layers = np.array([1,50,50,50,50,50,50,50,50,50,2]) #9 hidden layers
    layers = np.array([1,100,100,100,100,100,100,2])
    # layers = np.array([1,50,50,50,50,2])
    PINN = Sequentialmodel(layers)
    PINN.to(device)

    'Neural Network Summary'
    print(PINN)

    params = list(PINN.parameters())
    
    optimizer = torch.optim.LBFGS(PINN.parameters(), lr=0.25, 
                              max_iter = 10, 
                              max_eval = 15, 
                              tolerance_grad = 1e-5, 
                              tolerance_change = 1e-5, 
                              history_size = 100, 
                              line_search_fn = 'strong_wolfe')
   

    train_model(max_iter,reps)

    
    torch.save(PINN.state_dict(),label+'_'+str(reps)+'.pt')
    train_loss_full.append(train_loss)
    test_mse_full.append(test_mse_loss)
    test_re_full.append(test_re_loss)
    beta_full.append(beta_val)    
    
    print('Training time: %.2f' % (elapsed_time[reps]))

mdic = {"train_loss": train_loss_full,"test_mse_loss": test_mse_full, "test_re_loss": test_re_full, "Time": elapsed_time, "beta": beta_full, "label": label, "Thresh Time": time_threshold,"Thresh epoch": epoch_threshold}
savemat(label+'.mat', mdic)
# Out:
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=1, out_features=100, bias=True)
#     (1-5): 5 x Linear(in_features=100, out_features=100, bias=True)
#     (6): Linear(in_features=100, out_features=2, bias=True)
#   )
# )
# 0
# 0 Train Loss 0.7726171 Test MSE 0 Test RE 0
# 1 Train Loss 0.72335297 Test MSE 0 Test RE 0
# 2 Train Loss 0.517167 Test MSE 0 Test RE 0
# 3 Train Loss 0.32135582 Test MSE 0 Test RE 0
# 4 Train Loss 0.28516543 Test MSE 0 Test RE 0
# 5 Train Loss 0.24674597 Test MSE 0 Test RE 0
# 6 Train Loss 0.24068189 Test MSE 0 Test RE 0
# 7 Train Loss 0.2243917 Test MSE 0 Test RE 0
# 8 Train Loss 0.21061128 Test MSE 0 Test RE 0
# 9 Train Loss 0.20473486 Test MSE 0 Test RE 0
# 10 Train Loss 0.20293051 Test MSE 0 Test RE 0
# 11 Train Loss 0.19917743 Test MSE 0 Test RE 0
# 12 Train Loss 0.19467425 Test MSE 0 Test RE 0
# 13 Train Loss 0.19287951 Test MSE 0 Test RE 0
# 14 Train Loss 0.19145344 Test MSE 0 Test RE 0
# 15 Train Loss 0.19087602 Test MSE 0 Test RE 0
# 16 Train Loss 0.18944867 Test MSE 0 Test RE 0
# 17 Train Loss 0.18737479 Test MSE 0 Test RE 0
# 18 Train Loss 0.18156266 Test MSE 0 Test RE 0
# 19 Train Loss 0.17691253 Test MSE 0 Test RE 0
# 20 Train Loss 0.17535213 Test MSE 0 Test RE 0
# 21 Train Loss 0.17361085 Test MSE 0 Test RE 0
# 22 Train Loss 0.17267856 Test MSE 0 Test RE 0
# 23 Train Loss 0.17167762 Test MSE 0 Test RE 0
# 24 Train Loss 0.17158087 Test MSE 0 Test RE 0
# 25 Train Loss 0.17078963 Test MSE 0 Test RE 0
# 26 Train Loss 0.16968596 Test MSE 0 Test RE 0
# 27 Train Loss 0.16964142 Test MSE 0 Test RE 0
# 28 Train Loss 0.16963391 Test MSE 0 Test RE 0
# 29 Train Loss 0.1696275 Test MSE 0 Test RE 0
# 30 Train Loss 0.16962072 Test MSE 0 Test RE 0
# 31 Train Loss 0.16961226 Test MSE 0 Test RE 0
# 32 Train Loss 0.16960238 Test MSE 0 Test RE 0
# 33 Train Loss 0.16938946 Test MSE 0 Test RE 0
# 34 Train Loss 0.16930667 Test MSE 0 Test RE 0
# 35 Train Loss 0.16929805 Test MSE 0 Test RE 0
# 36 Train Loss 0.16928959 Test MSE 0 Test RE 0
# 37 Train Loss 0.16927981 Test MSE 0 Test RE 0
# 38 Train Loss 0.16925824 Test MSE 0 Test RE 0
# 39 Train Loss 0.16918755 Test MSE 0 Test RE 0
# 40 Train Loss 0.16918008 Test MSE 0 Test RE 0
# 41 Train Loss 0.16917388 Test MSE 0 Test RE 0
# 42 Train Loss 0.16916837 Test MSE 0 Test RE 0
# 43 Train Loss 0.16916303 Test MSE 0 Test RE 0
# 44 Train Loss 0.16915712 Test MSE 0 Test RE 0
# 45 Train Loss 0.1691502 Test MSE 0 Test RE 0
# 46 Train Loss 0.16914225 Test MSE 0 Test RE 0
# 47 Train Loss 0.16913287 Test MSE 0 Test RE 0
# 48 Train Loss 0.16878697 Test MSE 0 Test RE 0
# 49 Train Loss 0.1684936 Test MSE 0 Test RE 0
# 50 Train Loss 0.16848525 Test MSE 0 Test RE 0
# 51 Train Loss 0.16847672 Test MSE 0 Test RE 0
# 52 Train Loss 0.1684683 Test MSE 0 Test RE 0
# 53 Train Loss 0.1684584 Test MSE 0 Test RE 0
# 54 Train Loss 0.16827194 Test MSE 0 Test RE 0
# 55 Train Loss 0.16810106 Test MSE 0 Test RE 0
# 56 Train Loss 0.16798303 Test MSE 0 Test RE 0
# 57 Train Loss 0.16797492 Test MSE 0 Test RE 0
# 58 Train Loss 0.16796717 Test MSE 0 Test RE 0
# 59 Train Loss 0.16796032 Test MSE 0 Test RE 0
# 60 Train Loss 0.16795416 Test MSE 0 Test RE 0
# 61 Train Loss 0.16794826 Test MSE 0 Test RE 0
# 62 Train Loss 0.16794382 Test MSE 0 Test RE 0
# 63 Train Loss 0.16793938 Test MSE 0 Test RE 0
# 64 Train Loss 0.16793495 Test MSE 0 Test RE 0
# 65 Train Loss 0.16793108 Test MSE 0 Test RE 0
# 66 Train Loss 0.16792645 Test MSE 0 Test RE 0
# 67 Train Loss 0.16792199 Test MSE 0 Test RE 0
# 68 Train Loss 0.16791712 Test MSE 0 Test RE 0
# 69 Train Loss 0.16791221 Test MSE 0 Test RE 0
# 70 Train Loss 0.1679063 Test MSE 0 Test RE 0
# 71 Train Loss 0.16790031 Test MSE 0 Test RE 0
# 72 Train Loss 0.16789511 Test MSE 0 Test RE 0
# 73 Train Loss 0.16788967 Test MSE 0 Test RE 0
# 74 Train Loss 0.16788526 Test MSE 0 Test RE 0
# 75 Train Loss 0.16787945 Test MSE 0 Test RE 0
# 76 Train Loss 0.16787489 Test MSE 0 Test RE 0
# 77 Train Loss 0.16787034 Test MSE 0 Test RE 0
# 78 Train Loss 0.16786397 Test MSE 0 Test RE 0
# 79 Train Loss 0.1678559 Test MSE 0 Test RE 0
# 80 Train Loss 0.16784656 Test MSE 0 Test RE 0
# 81 Train Loss 0.16783741 Test MSE 0 Test RE 0
# 82 Train Loss 0.16782981 Test MSE 0 Test RE 0
# 83 Train Loss 0.16779669 Test MSE 0 Test RE 0
# 84 Train Loss 0.16774353 Test MSE 0 Test RE 0
# 85 Train Loss 0.16773649 Test MSE 0 Test RE 0
# 86 Train Loss 0.1677269 Test MSE 0 Test RE 0
# 87 Train Loss 0.1675467 Test MSE 0 Test RE 0
# 88 Train Loss 0.16748485 Test MSE 0 Test RE 0
# 89 Train Loss 0.16747819 Test MSE 0 Test RE 0
# 90 Train Loss 0.16747314 Test MSE 0 Test RE 0
# 91 Train Loss 0.16746853 Test MSE 0 Test RE 0
# 92 Train Loss 0.1674644 Test MSE 0 Test RE 0
# 93 Train Loss 0.16746019 Test MSE 0 Test RE 0
# 94 Train Loss 0.16745488 Test MSE 0 Test RE 0
# 95 Train Loss 0.16744673 Test MSE 0 Test RE 0
# 96 Train Loss 0.16732001 Test MSE 0 Test RE 0
# 97 Train Loss 0.16730013 Test MSE 0 Test RE 0
# 98 Train Loss 0.16715038 Test MSE 0 Test RE 0
# 99 Train Loss 0.16687278 Test MSE 0 Test RE 0
# 100 Train Loss 0.16684179 Test MSE 0 Test RE 0
# 101 Train Loss 0.16683663 Test MSE 0 Test RE 0
# 102 Train Loss 0.16683269 Test MSE 0 Test RE 0
# 103 Train Loss 0.1668292 Test MSE 0 Test RE 0
# 104 Train Loss 0.16682555 Test MSE 0 Test RE 0
# 105 Train Loss 0.16682115 Test MSE 0 Test RE 0
# 106 Train Loss 0.1668162 Test MSE 0 Test RE 0
# 107 Train Loss 0.1668108 Test MSE 0 Test RE 0
# 108 Train Loss 0.16680497 Test MSE 0 Test RE 0
# 109 Train Loss 0.16679792 Test MSE 0 Test RE 0
# 110 Train Loss 0.16678795 Test MSE 0 Test RE 0
# 111 Train Loss 0.16658862 Test MSE 0 Test RE 0
# 112 Train Loss 0.16634434 Test MSE 0 Test RE 0
# 113 Train Loss 0.16633822 Test MSE 0 Test RE 0
# 114 Train Loss 0.1663327 Test MSE 0 Test RE 0
# 115 Train Loss 0.16632757 Test MSE 0 Test RE 0
# 116 Train Loss 0.16632344 Test MSE 0 Test RE 0
# 117 Train Loss 0.16631928 Test MSE 0 Test RE 0
# 118 Train Loss 0.16631511 Test MSE 0 Test RE 0
# 119 Train Loss 0.16631138 Test MSE 0 Test RE 0
# 120 Train Loss 0.16630793 Test MSE 0 Test RE 0
# 121 Train Loss 0.1663034 Test MSE 0 Test RE 0
# 122 Train Loss 0.16629839 Test MSE 0 Test RE 0
# 123 Train Loss 0.1662941 Test MSE 0 Test RE 0
# 124 Train Loss 0.16628945 Test MSE 0 Test RE 0
# 125 Train Loss 0.16628443 Test MSE 0 Test RE 0
# 126 Train Loss 0.16627842 Test MSE 0 Test RE 0
# 127 Train Loss 0.16627179 Test MSE 0 Test RE 0
# 128 Train Loss 0.16626483 Test MSE 0 Test RE 0
# 129 Train Loss 0.1662577 Test MSE 0 Test RE 0
# 130 Train Loss 0.16625023 Test MSE 0 Test RE 0
# 131 Train Loss 0.16624169 Test MSE 0 Test RE 0
# 132 Train Loss 0.16623327 Test MSE 0 Test RE 0
# 133 Train Loss 0.1662249 Test MSE 0 Test RE 0
# 134 Train Loss 0.16621746 Test MSE 0 Test RE 0
# 135 Train Loss 0.16620915 Test MSE 0 Test RE 0
# 136 Train Loss 0.16617793 Test MSE 0 Test RE 0
# 137 Train Loss 0.1660502 Test MSE 0 Test RE 0
# 138 Train Loss 0.16589272 Test MSE 0 Test RE 0
# 139 Train Loss 0.16588406 Test MSE 0 Test RE 0
# 140 Train Loss 0.16587645 Test MSE 0 Test RE 0
# 141 Train Loss 0.16587012 Test MSE 0 Test RE 0
# 142 Train Loss 0.165865 Test MSE 0 Test RE 0
# 143 Train Loss 0.16586126 Test MSE 0 Test RE 0
# 144 Train Loss 0.1658584 Test MSE 0 Test RE 0
# 145 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 146 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 147 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 148 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 149 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 150 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 151 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 152 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 153 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 154 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 155 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 156 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 157 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 158 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 159 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 160 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 161 Train Loss 0.16585615 Test MSE 0 Test RE 0
# 162 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 163 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 164 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 165 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 166 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 167 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 168 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 169 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 170 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 171 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 172 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 173 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 174 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 175 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 176 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 177 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 178 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 179 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 180 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 181 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 182 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 183 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 184 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 185 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 186 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 187 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 188 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 189 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 190 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 191 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 192 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 193 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 194 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 195 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 196 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 197 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 198 Train Loss 0.16585617 Test MSE 0 Test RE 0
# 199 Train Loss 0.16585617 Test MSE 0 Test RE 0
# Training time: 20.98
# Training time: 20.98

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

count_parameters(PINN)
# Out:
# 51502

# %%
u_pred = PINN.test()[:,0]
# plt.plot(x,u_pred,'r')
# plt.plot(y_true,'b')

# %%
data_mat = loadmat('Vanderpol_ODEsolver.mat')
y = data_mat['y'][:,0]
t = data_mat['t']

fig,ax = plt.subplots()
ax.plot(t,y,'b',linewidth = 2,label = 'Numerical Solver')
ax.plot(x,u_pred,'r-.',linewidth = 2,label = 'Vanilla PINN')
ax.set_xlabel('Time(s)')
ax.set_ylabel('Value')
ax.set_title('van der Pol Oscillator')
ax.legend(loc = 3)
# plt.savefig('Simple_PINN_VanderPol.svg',format = 'svg')
# plt.savefig('Simple_PINN_VanderPol.png',format = 'png')
