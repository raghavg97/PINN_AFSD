# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from torch.nn.parameter import Parameter
import matplotlib as mpl

import numpy as np
import time
#from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat
from scipy.io import loadmat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:0

# %%
# def true_2D_1(xt): #True function for 2D_1 Klein Gordon Equation x \in [-50,50] , t \in [0,10]
#     x = xt[:,0].reshape(-1,1)
#     t = xt[:,1].reshape(-1,1)
#     y = x*np.cos(5*np.pi*t) + np.power(x*t,3)
#     return y.reshape(-1,1)

# %%
pi = np.pi
Re = 100
level = "high"
label = "NS_vPINN_" 

x = np.linspace(0,1,101).reshape(-1,1)
y = np.linspace(0,1,101).reshape(-1,1)
t = np.linspace(0,1,101).reshape(-1,1)

X,Y,T = np.meshgrid(x,y,t)

X = X.flatten('F').reshape(-1,1)
Y = Y.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xyt = np.hstack((X,Y,T))

# y_true = true_2D_1(xt)
# y_true_norm = np.linalg.norm(y_true,2)

#bound_pts_idx = ((X == -5) + (X == 5) + (T == 0)).reshape(-1,)

#xt_bound = xt[bound_pts_idx,:]
#y_bound = y_true[bound_pts_idx,:]


xyt_test_tensor = torch.from_numpy(xyt).float().to(device)


lb_xyt = xyt[0]
ub_xyt = xyt[-1]

# %%
def trainingdata(N_I,N_B,N_f,seed):
    '''Boundary Conditions''' 
    
    np.random.seed(seed)
    x_I = np.random.uniform(size = N_I).reshape(-1,1)
    y_I = np.random.uniform(size = N_I).reshape(-1,1)
    t_I = np.zeros((N_I,1))
    xyt_I = np.hstack((x_I,y_I,t_I))
    u_I = np.zeros((N_I,1))
    v_I = np.zeros((N_I,1))
    p_I = np.zeros((N_I,1))
    
    #Top
    x_BC1 = np.random.uniform(size = N_B).reshape(-1,1)
    y_BC1 = np.ones((N_B,1))
    t_BC1 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC1 = np.hstack((x_BC1,y_BC1,t_BC1))
    u_BC1 = np.ones((N_B,1))
    v_BC1 = np.zeros((N_B,1))
    
    #Right
    x_BC2 = np.ones((N_B,1))
    y_BC2 = np.random.uniform(size = N_B).reshape(-1,1)
    t_BC2 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC2 = np.hstack((x_BC2,y_BC2,t_BC2))
    u_BC2 = np.zeros((N_B,1))
    v_BC2 = np.zeros((N_B,1))

    #Bottom
    x_BC3 = np.random.uniform(size = N_B).reshape(-1,1)
    y_BC3 = np.zeros((N_B,1))
    t_BC3 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC3 = np.hstack((x_BC3,y_BC3,t_BC3))
    u_BC3 = np.zeros((N_B,1))
    v_BC3 = np.zeros((N_B,1))
    
    #Left
    x_BC4 = np.zeros((N_B,1))
    y_BC4 = np.random.uniform(size = N_B).reshape(-1,1)
    t_BC4 = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_BC4 = np.hstack((x_BC4,y_BC4,t_BC4))
    u_BC4 = np.zeros((N_B,1))
    v_BC4 = np.zeros((N_B,1))
    
    
    xyt_BC = np.vstack((xyt_BC1,xyt_BC2,xyt_BC3,xyt_BC4))
    u_BC = np.vstack((u_BC1,u_BC2,u_BC3,u_BC4))
    v_BC = np.vstack((v_BC1,v_BC2,v_BC3,v_BC4))

    x_p = np.zeros((N_B,1))
    y_p = np.zeros((N_B,1))
    t_p = np.random.uniform(size = N_B).reshape(-1,1)
    xyt_p = np.hstack((x_p,y_p,t_p))
    u_p = np.zeros((N_B,1))
    v_p = np.zeros((N_B,1))
    p_p = np.zeros((N_B,1))
    
    xyt_Ip = np.vstack((xyt_I,xyt_p))
    u_Ip = np.vstack((u_I,u_p))
    v_Ip = np.vstack((v_I,v_p))
    p_Ip = np.vstack((p_I,p_p))

    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    x01 = np.array([[0.0,1.0],[0.0,1.0],[0.0,1.0]])
    sampling = LHS(xlimits=x01,random_state =seed)
    samples = sampling(N_f)
    xyt_coll = lb_xyt + (ub_xyt - lb_xyt)*samples
    
    xyt_coll = np.vstack((xyt_coll, xyt_BC,xyt_I,xyt_p)) # append training points to collocation points 

    return xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip

# %%
class Sequentialmodel(nn.Module):
    
    def __init__(self,layers,beta_init):
        super().__init__() #call __init__ from parent class 
              
        'activation function'
        self.activation = nn.Tanh()

        'loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        'Initialise neural network as a list using nn.Modulelist'  
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
            
        
        beta_mean = 1.0*torch.ones((100,len(layers)-2))
        beta_std = 0.01*torch.ones((100,len(layers)-2))
        
        self.beta = Parameter(torch.normal(beta_mean,beta_std))
        self.beta.requiresGrad = True

            
    'foward pass'
    def forward(self,xyt):
        if torch.is_tensor(xyt) != True:         
            xt = torch.from_numpy(xyt)                
        
        ubxyt = torch.from_numpy(ub_xyt).float().to(device)
        lbxyt = torch.from_numpy(lb_xyt).float().to(device)
    
                      
        #preprocessing input 
        xyt = 2.0*(xyt - lbxyt)/(ubxyt - lbxyt) - 1.0
        
        #convert to float
        a = xyt.float()
        
        for i in range(len(layers)-2):
            z = self.linears[i](a)
            z1 = self.activation(z)
            a = z1 + self.beta[:,i]*z*z1            
        
        a = self.linears[-1](a) 
         
        return a
                        
    def loss_BC(self,xyt_BC,u_BC,v_BC):
                
        uvp = self.forward(xyt_BC)
        
        loss_bc_u = self.loss_function(uvp[:,0:1],u_BC)
        loss_bc_v = self.loss_function(uvp[:,1:2],v_BC)
        
        # psi_p_pred = self.forward(torch.cat((x1,y1,t1),dim =1))
        # psi = psi_p_pred[:,0:1]
        # p_pred = psi_p_pred[:,1:2]
                
        return loss_bc_u + loss_bc_v
    
    def loss_Ip(self,xyt_Ip,u_Ip,v_Ip,p_Ip):
                
        uvp = self.forward(xyt_Ip)
        
        loss_ip_u = self.loss_function(uvp[:,0:1],u_Ip)
        loss_ip_v = self.loss_function(uvp[:,1:2],v_Ip)
        loss_ip_p = self.loss_function(uvp[:,2:3],p_Ip)
        
        # psi_p_pred = self.forward(torch.cat((x1,y1,t1),dim =1))
        # psi = psi_p_pred[:,0:1]
        # p_pred = psi_p_pred[:,1:2]
                
        return loss_ip_u + loss_ip_v+loss_ip_p
    
    def loss_PDE(self, xyt_coll, f_hat):
        
        g = xyt_coll.clone()             
        g.requires_grad = True
        uvp = self.forward(g) 
        
        u = uvp[:,0:1]
        v = uvp[:,1:2]
        p = uvp[:,2:3]
        
        
        #u
        u_xyt = autograd.grad(u,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
    
        u_xx_yy_tt = autograd.grad(u_xyt,g,torch.ones(xyt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        du_dx = u_xyt[:,[0]]
        du_dy = u_xyt[:,[1]]
        du_dt = u_xyt[:,[2]]
        
        d2u_dx2 = u_xx_yy_tt[:,[0]]
        d2u_dy2 = u_xx_yy_tt[:,[1]]
        
        #v
        v_xyt = autograd.grad(v,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]

        v_xx_yy_tt = autograd.grad(v_xyt,g,torch.ones(xyt_coll.shape).to(device), create_graph=True,allow_unused = True)[0]

        dv_dx = v_xyt[:,[0]]
        dv_dy = v_xyt[:,[1]]
        dv_dt = v_xyt[:,[2]]
        
        d2v_dx2 = v_xx_yy_tt[:,[0]]
        d2v_dy2 = v_xx_yy_tt[:,[1]]
        
        #p
        p_xyt = autograd.grad(p,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]

        dp_dx = p_xyt[:,[0]]
        dp_dy = p_xyt[:,[1]]
    
        
        
        f_u = du_dt + u*du_dx + v*du_dy + dp_dx - (d2u_dx2 + d2u_dy2)/Re
        f_v = dv_dt + u*dv_dx + v*dv_dy + dp_dy - (d2v_dx2 + d2v_dy2)/Re
        
        
        loss_f_u = self.loss_function(f_u,f_hat)
        loss_f_v = self.loss_function(f_v,f_hat)
                
        return loss_f_u + loss_f_v
    
    
    def loss_NBC(self,xyt_coll,N_hat):
        g = xyt_coll.clone()             
        g.requires_grad = True
        uvp = self.forward(g)
        
        u = uvp[:,0:1]
        v = uvp[:,1:2]
        
        u_xyt = autograd.grad(u,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        v_xyt = autograd.grad(v,g,torch.ones([xyt_coll.shape[0], 1]).to(device), retain_graph=True, create_graph=True,allow_unused = True)[0]
        
        du_dx = u_xyt[:,[0]]
        dv_dy = v_xyt[:,[1]]
        
        loss_nbc = self.loss_function(du_dx + dv_dy, N_hat)
                
        return loss_nbc
    
    
    def loss(self,xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat):

        loss_BC = self.loss_BC(xyt_BC,u_BC,v_BC)
        loss_Ip = self.loss_Ip(xyt_Ip,u_Ip,v_Ip,p_Ip)
        loss_NBC = self.loss_NBC(xyt_coll,N_hat)
        loss_f = self.loss_PDE(xyt_coll,f_hat)
        
        loss_val = loss_BC + loss_f + loss_NBC +loss_Ip
        
        return loss_val
         
    'test neural network'
    def test(self):
        y_pred = self.forward(xt_test_tensor)
        y_pred = y_pred.cpu().detach().numpy()
   
        return y_pred
    
    def test_loss(self):
        # y_pred = self.test()
        
        # test_mse = np.mean(np.square(y_pred.reshape(-1,1) - y_true.reshape(-1,1)))
        # test_re = np.linalg.norm(y_pred.reshape(-1,1) - y_true.reshape(-1,1),2)/y_true_norm
        test_mse = 0
        test_re = 0
        
        return test_mse, test_re

# %%
def data_update(loss_np):
    train_loss.append(loss_np)
    beta_val.append(PINN.beta.cpu().detach().numpy())
    
    test_mse, test_re = PINN.test_loss()
    test_mse_loss.append(test_mse)
    test_re_loss.append(test_re)

# %%
def train_step(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat,seed):
    
    def closure():
        optimizer.zero_grad()
        loss = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat)
        loss.backward()
        #print(loss.cpu().detach().numpy())
        return loss

    optimizer.step(closure)

# %%
def train_model(max_iter,rep): 
    print(rep) 
    torch.manual_seed(rep*9)
    start_time = time.time() 
    thresh_flag = 0

    xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip = trainingdata(N_I,N_B,N_f,rep*11)
    xyt_coll = torch.from_numpy(xyt_coll).float().to(device)
    xyt_BC = torch.from_numpy(xyt_BC).float().to(device)
    u_BC = torch.from_numpy(u_BC).float().to(device)
    v_BC = torch.from_numpy(v_BC).float().to(device)
    
    xyt_Ip = torch.from_numpy(xyt_Ip).float().to(device)
    u_Ip = torch.from_numpy(u_Ip).float().to(device)
    v_Ip = torch.from_numpy(v_Ip).float().to(device)
    p_Ip = torch.from_numpy(p_Ip).float().to(device)
    
    f_hat = torch.zeros(xyt_coll.shape[0],1).to(device)
    N_hat = torch.zeros(xyt_coll.shape[0],1).to(device)
    
    loss_np = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat).cpu().detach().numpy()
    data_update(loss_np)
    for i in range(max_iter):
        if(np.isnan(loss_np) == False):
            train_step(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat,i)
            loss_np = PINN.loss(xyt_coll, xyt_BC,u_BC,v_BC, xyt_Ip, u_Ip,v_Ip, p_Ip,f_hat,N_hat).cpu().detach().numpy()
        

        data_update(loss_np)
        
        print(i,"Train Loss",train_loss[-1],"Test MSE",test_mse_loss[-1],"Test RE",test_re_loss[-1])   
        
      

    elapsed_time[rep] = time.time() - start_time  
    print('Training time: %.2f' % (elapsed_time[rep]))

# %%
max_reps = 1 #10
max_iter = 500 #200

train_loss_full = []
test_mse_full = []
test_re_full = []
beta_full = []
elapsed_time= np.zeros((max_reps,1))
time_threshold = np.empty((max_reps,1))
time_threshold[:] = np.nan
epoch_threshold = max_iter*np.ones((max_reps,1))

beta_init = 0

N_I = 2000  #Total number of data points for 'y'
N_B = 2000
N_f = 20000 #Total number of collocation points

for reps in range(max_reps):
    print(label)
    print(reps)
    train_loss = []
    test_mse_loss = []
    test_re_loss = []
    beta_val = []

    torch.manual_seed(reps*36)

    layers = np.array([3,100,100,100,100,100,3]) #9 hidden layers
    # layers = np.array([2,50,50,50,50,50,50,50,1])

    PINN = Sequentialmodel(layers,beta_init)

    PINN.to(device)

    'Neural Network Summary'
    print(PINN)

    params = list(PINN.parameters())


    optimizer = torch.optim.LBFGS(PINN.parameters(), lr=1, 
                            max_iter = 20, 
                            max_eval = 30, 
                            tolerance_grad = 1e-8, 
                            tolerance_change = 1e-8, 
                            history_size = 100, 
                            line_search_fn = 'strong_wolfe')




    nan_flag = train_model(max_iter,reps)



    torch.save(PINN.state_dict(),label+'_'+str(reps)+'.pt')
    train_loss_full.append(train_loss)
    test_mse_full.append(test_mse_loss)
    test_re_full.append(test_re_loss)
    #elapsed_time[reps] = time.time() - start_time
    beta_full.append(beta_val)


  #print('Training time: %.2f' % (elapsed_time[reps]))

mdic = {"train_loss": train_loss_full,"test_mse_loss": test_mse_full,"test_re_loss": test_re_full,"Time": elapsed_time, "beta": beta_full, "label": label,"Thresh Time": time_threshold,"Thresh epoch": epoch_threshold}
savemat(label+'.mat', mdic)
# Out:
# NS_vPINN_
# 0
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=3, out_features=100, bias=True)
#     (1-4): 4 x Linear(in_features=100, out_features=100, bias=True)
#     (5): Linear(in_features=100, out_features=3, bias=True)
#   )
# )
# 0
# 0 Train Loss 0.08082655 Test MSE 0 Test RE 0
# 1 Train Loss 0.048836485 Test MSE 0 Test RE 0
# 2 Train Loss 0.032669984 Test MSE 0 Test RE 0
# 3 Train Loss 0.024785642 Test MSE 0 Test RE 0
# 4 Train Loss 0.022249619 Test MSE 0 Test RE 0
# 5 Train Loss 0.020767394 Test MSE 0 Test RE 0
# 6 Train Loss 0.019831322 Test MSE 0 Test RE 0
# 7 Train Loss 0.018985549 Test MSE 0 Test RE 0
# 8 Train Loss 0.01843406 Test MSE 0 Test RE 0
# 9 Train Loss 0.017926963 Test MSE 0 Test RE 0
# 10 Train Loss 0.017430464 Test MSE 0 Test RE 0
# 11 Train Loss 0.017123327 Test MSE 0 Test RE 0
# 12 Train Loss 0.016818646 Test MSE 0 Test RE 0
# 13 Train Loss 0.016531043 Test MSE 0 Test RE 0
# 14 Train Loss 0.01619282 Test MSE 0 Test RE 0
# 15 Train Loss 0.015934596 Test MSE 0 Test RE 0
# 16 Train Loss 0.015656756 Test MSE 0 Test RE 0
# 17 Train Loss 0.015416043 Test MSE 0 Test RE 0
# 18 Train Loss 0.015222387 Test MSE 0 Test RE 0
# 19 Train Loss 0.015043107 Test MSE 0 Test RE 0
# 20 Train Loss 0.014866266 Test MSE 0 Test RE 0
# 21 Train Loss 0.014665161 Test MSE 0 Test RE 0
# 22 Train Loss 0.014519247 Test MSE 0 Test RE 0
# 23 Train Loss 0.014365224 Test MSE 0 Test RE 0
# 24 Train Loss 0.014216559 Test MSE 0 Test RE 0
# 25 Train Loss 0.014074467 Test MSE 0 Test RE 0
# 26 Train Loss 0.013935882 Test MSE 0 Test RE 0
# 27 Train Loss 0.013755738 Test MSE 0 Test RE 0
# 28 Train Loss 0.01358914 Test MSE 0 Test RE 0
# 29 Train Loss 0.01341893 Test MSE 0 Test RE 0
# 30 Train Loss 0.01324476 Test MSE 0 Test RE 0
# 31 Train Loss 0.01308199 Test MSE 0 Test RE 0
# 32 Train Loss 0.012884531 Test MSE 0 Test RE 0
# 33 Train Loss 0.012735463 Test MSE 0 Test RE 0
# 34 Train Loss 0.012565648 Test MSE 0 Test RE 0
# 35 Train Loss 0.012391214 Test MSE 0 Test RE 0
# 36 Train Loss 0.012232665 Test MSE 0 Test RE 0
# 37 Train Loss 0.012063376 Test MSE 0 Test RE 0
# 38 Train Loss 0.011874708 Test MSE 0 Test RE 0
# 39 Train Loss 0.011680848 Test MSE 0 Test RE 0
# 40 Train Loss 0.01149903 Test MSE 0 Test RE 0
# 41 Train Loss 0.011331525 Test MSE 0 Test RE 0
# 42 Train Loss 0.011166809 Test MSE 0 Test RE 0
# 43 Train Loss 0.010980019 Test MSE 0 Test RE 0
# 44 Train Loss 0.010805969 Test MSE 0 Test RE 0
# 45 Train Loss 0.010663321 Test MSE 0 Test RE 0
# 46 Train Loss 0.010519912 Test MSE 0 Test RE 0
# 47 Train Loss 0.010363033 Test MSE 0 Test RE 0
# 48 Train Loss 0.010217519 Test MSE 0 Test RE 0
# 49 Train Loss 0.010101121 Test MSE 0 Test RE 0
# 50 Train Loss 0.009991818 Test MSE 0 Test RE 0
# 51 Train Loss 0.009890428 Test MSE 0 Test RE 0
# 52 Train Loss 0.00979515 Test MSE 0 Test RE 0
# 53 Train Loss 0.009674575 Test MSE 0 Test RE 0
# 54 Train Loss 0.0095737185 Test MSE 0 Test RE 0
# 55 Train Loss 0.009469217 Test MSE 0 Test RE 0
# 56 Train Loss 0.009371936 Test MSE 0 Test RE 0
# 57 Train Loss 0.009290023 Test MSE 0 Test RE 0
# 58 Train Loss 0.009200187 Test MSE 0 Test RE 0
# 59 Train Loss 0.009116932 Test MSE 0 Test RE 0
# 60 Train Loss 0.009032296 Test MSE 0 Test RE 0
# 61 Train Loss 0.008943025 Test MSE 0 Test RE 0
# 62 Train Loss 0.008863656 Test MSE 0 Test RE 0
# 63 Train Loss 0.00878123 Test MSE 0 Test RE 0
# 64 Train Loss 0.008700884 Test MSE 0 Test RE 0
# 65 Train Loss 0.008624298 Test MSE 0 Test RE 0
# 66 Train Loss 0.0085695665 Test MSE 0 Test RE 0
# 67 Train Loss 0.0085091 Test MSE 0 Test RE 0
# 68 Train Loss 0.008447363 Test MSE 0 Test RE 0
# 69 Train Loss 0.008385977 Test MSE 0 Test RE 0
# 70 Train Loss 0.008320129 Test MSE 0 Test RE 0
# 71 Train Loss 0.008268634 Test MSE 0 Test RE 0
# 72 Train Loss 0.008219784 Test MSE 0 Test RE 0
# 73 Train Loss 0.008162052 Test MSE 0 Test RE 0
# 74 Train Loss 0.008093949 Test MSE 0 Test RE 0
# 75 Train Loss 0.00804416 Test MSE 0 Test RE 0
# 76 Train Loss 0.007995577 Test MSE 0 Test RE 0
# 77 Train Loss 0.007947122 Test MSE 0 Test RE 0
# 78 Train Loss 0.007897237 Test MSE 0 Test RE 0
# 79 Train Loss 0.007852119 Test MSE 0 Test RE 0
# 80 Train Loss 0.0078081694 Test MSE 0 Test RE 0
# 81 Train Loss 0.0077600894 Test MSE 0 Test RE 0
# 82 Train Loss 0.0077094883 Test MSE 0 Test RE 0
# 83 Train Loss 0.0076658847 Test MSE 0 Test RE 0
# 84 Train Loss 0.007622603 Test MSE 0 Test RE 0
# 85 Train Loss 0.0075810766 Test MSE 0 Test RE 0
# 86 Train Loss 0.007542148 Test MSE 0 Test RE 0
# 87 Train Loss 0.00749702 Test MSE 0 Test RE 0
# 88 Train Loss 0.007461953 Test MSE 0 Test RE 0
# 89 Train Loss 0.007418968 Test MSE 0 Test RE 0
# 90 Train Loss 0.007379092 Test MSE 0 Test RE 0
# 91 Train Loss 0.0073403413 Test MSE 0 Test RE 0
# 92 Train Loss 0.0072895293 Test MSE 0 Test RE 0
# 93 Train Loss 0.007240881 Test MSE 0 Test RE 0
# 94 Train Loss 0.0071946527 Test MSE 0 Test RE 0
# 95 Train Loss 0.0071543506 Test MSE 0 Test RE 0
# 96 Train Loss 0.0071101617 Test MSE 0 Test RE 0
# 97 Train Loss 0.00706618 Test MSE 0 Test RE 0
# 98 Train Loss 0.0070203166 Test MSE 0 Test RE 0
# 99 Train Loss 0.0069841724 Test MSE 0 Test RE 0
# 100 Train Loss 0.0069441292 Test MSE 0 Test RE 0
# 101 Train Loss 0.0069021285 Test MSE 0 Test RE 0
# 102 Train Loss 0.0068632714 Test MSE 0 Test RE 0
# 103 Train Loss 0.0068130638 Test MSE 0 Test RE 0
# 104 Train Loss 0.006779214 Test MSE 0 Test RE 0
# 105 Train Loss 0.0067465357 Test MSE 0 Test RE 0
# 106 Train Loss 0.006713874 Test MSE 0 Test RE 0
# 107 Train Loss 0.006680138 Test MSE 0 Test RE 0
# 108 Train Loss 0.006637813 Test MSE 0 Test RE 0
# 109 Train Loss 0.0066061947 Test MSE 0 Test RE 0
# 110 Train Loss 0.00657056 Test MSE 0 Test RE 0
# 111 Train Loss 0.00653803 Test MSE 0 Test RE 0
# 112 Train Loss 0.006498907 Test MSE 0 Test RE 0
# 113 Train Loss 0.006462578 Test MSE 0 Test RE 0
# 114 Train Loss 0.006428723 Test MSE 0 Test RE 0
# 115 Train Loss 0.006399889 Test MSE 0 Test RE 0
# 116 Train Loss 0.0063681398 Test MSE 0 Test RE 0
# 117 Train Loss 0.006342328 Test MSE 0 Test RE 0
# 118 Train Loss 0.006314207 Test MSE 0 Test RE 0
# 119 Train Loss 0.00628934 Test MSE 0 Test RE 0
# 120 Train Loss 0.006259846 Test MSE 0 Test RE 0
# 121 Train Loss 0.006234563 Test MSE 0 Test RE 0
# 122 Train Loss 0.0062088794 Test MSE 0 Test RE 0
# 123 Train Loss 0.006175603 Test MSE 0 Test RE 0
# 124 Train Loss 0.0061525917 Test MSE 0 Test RE 0
# 125 Train Loss 0.0061251502 Test MSE 0 Test RE 0
# 126 Train Loss 0.006097052 Test MSE 0 Test RE 0
# 127 Train Loss 0.0060700052 Test MSE 0 Test RE 0
# 128 Train Loss 0.0060465895 Test MSE 0 Test RE 0
# 129 Train Loss 0.0060227215 Test MSE 0 Test RE 0
# 130 Train Loss 0.0059942584 Test MSE 0 Test RE 0
# 131 Train Loss 0.005961279 Test MSE 0 Test RE 0
# 132 Train Loss 0.005931623 Test MSE 0 Test RE 0
# 133 Train Loss 0.0059041344 Test MSE 0 Test RE 0
# 134 Train Loss 0.00587968 Test MSE 0 Test RE 0
# 135 Train Loss 0.00585515 Test MSE 0 Test RE 0
# 136 Train Loss 0.0058272905 Test MSE 0 Test RE 0
# 137 Train Loss 0.0058010933 Test MSE 0 Test RE 0
# 138 Train Loss 0.00577704 Test MSE 0 Test RE 0
# 139 Train Loss 0.0057544066 Test MSE 0 Test RE 0
# 140 Train Loss 0.0057320963 Test MSE 0 Test RE 0
# 141 Train Loss 0.0057097715 Test MSE 0 Test RE 0
# 142 Train Loss 0.005683437 Test MSE 0 Test RE 0
# 143 Train Loss 0.0056584156 Test MSE 0 Test RE 0
# 144 Train Loss 0.005636414 Test MSE 0 Test RE 0
# 145 Train Loss 0.005609057 Test MSE 0 Test RE 0
# 146 Train Loss 0.0055845673 Test MSE 0 Test RE 0
# 147 Train Loss 0.005560881 Test MSE 0 Test RE 0
# 148 Train Loss 0.005537651 Test MSE 0 Test RE 0
# 149 Train Loss 0.0055181254 Test MSE 0 Test RE 0
# 150 Train Loss 0.005493922 Test MSE 0 Test RE 0
# 151 Train Loss 0.005469722 Test MSE 0 Test RE 0
# 152 Train Loss 0.0054477635 Test MSE 0 Test RE 0
# 153 Train Loss 0.005428249 Test MSE 0 Test RE 0
# 154 Train Loss 0.005408583 Test MSE 0 Test RE 0
# 155 Train Loss 0.005387236 Test MSE 0 Test RE 0
# 156 Train Loss 0.0053664693 Test MSE 0 Test RE 0
# 157 Train Loss 0.0053482465 Test MSE 0 Test RE 0
# 158 Train Loss 0.00532564 Test MSE 0 Test RE 0
# 159 Train Loss 0.0053070206 Test MSE 0 Test RE 0
# 160 Train Loss 0.0052889944 Test MSE 0 Test RE 0
# 161 Train Loss 0.005270374 Test MSE 0 Test RE 0
# 162 Train Loss 0.005247531 Test MSE 0 Test RE 0
# 163 Train Loss 0.0052296123 Test MSE 0 Test RE 0
# 164 Train Loss 0.0052091023 Test MSE 0 Test RE 0
# 165 Train Loss 0.005192381 Test MSE 0 Test RE 0
# 166 Train Loss 0.0051717954 Test MSE 0 Test RE 0
# 167 Train Loss 0.005149544 Test MSE 0 Test RE 0
# 168 Train Loss 0.005131632 Test MSE 0 Test RE 0
# 169 Train Loss 0.005110696 Test MSE 0 Test RE 0
# 170 Train Loss 0.005087012 Test MSE 0 Test RE 0
# 171 Train Loss 0.005068565 Test MSE 0 Test RE 0
# 172 Train Loss 0.0050492985 Test MSE 0 Test RE 0
# 173 Train Loss 0.0050315987 Test MSE 0 Test RE 0
# 174 Train Loss 0.005014617 Test MSE 0 Test RE 0
# 175 Train Loss 0.004994051 Test MSE 0 Test RE 0
# 176 Train Loss 0.004973297 Test MSE 0 Test RE 0
# 177 Train Loss 0.0049532913 Test MSE 0 Test RE 0
# 178 Train Loss 0.0049288096 Test MSE 0 Test RE 0
# 179 Train Loss 0.0049063177 Test MSE 0 Test RE 0
# 180 Train Loss 0.00487996 Test MSE 0 Test RE 0
# 181 Train Loss 0.0048590666 Test MSE 0 Test RE 0
# 182 Train Loss 0.0048348485 Test MSE 0 Test RE 0
# 183 Train Loss 0.0048152446 Test MSE 0 Test RE 0
# 184 Train Loss 0.0047928817 Test MSE 0 Test RE 0
# 185 Train Loss 0.0047694324 Test MSE 0 Test RE 0
# 186 Train Loss 0.004746673 Test MSE 0 Test RE 0
# 187 Train Loss 0.004725924 Test MSE 0 Test RE 0
# 188 Train Loss 0.0047069117 Test MSE 0 Test RE 0
# 189 Train Loss 0.0046871128 Test MSE 0 Test RE 0
# 190 Train Loss 0.0046662567 Test MSE 0 Test RE 0
# 191 Train Loss 0.0046483837 Test MSE 0 Test RE 0
# 192 Train Loss 0.00462838 Test MSE 0 Test RE 0
# 193 Train Loss 0.004607586 Test MSE 0 Test RE 0
# 194 Train Loss 0.004588101 Test MSE 0 Test RE 0
# 195 Train Loss 0.004566862 Test MSE 0 Test RE 0
# 196 Train Loss 0.004547262 Test MSE 0 Test RE 0
# 197 Train Loss 0.004529362 Test MSE 0 Test RE 0
# 198 Train Loss 0.0045116115 Test MSE 0 Test RE 0
# 199 Train Loss 0.0044923346 Test MSE 0 Test RE 0
# 200 Train Loss 0.0044732355 Test MSE 0 Test RE 0
# 201 Train Loss 0.004454111 Test MSE 0 Test RE 0
# 202 Train Loss 0.004434595 Test MSE 0 Test RE 0
# 203 Train Loss 0.004415515 Test MSE 0 Test RE 0
# 204 Train Loss 0.004396952 Test MSE 0 Test RE 0
# 205 Train Loss 0.0043817973 Test MSE 0 Test RE 0
# 206 Train Loss 0.0043649543 Test MSE 0 Test RE 0
# 207 Train Loss 0.0043451446 Test MSE 0 Test RE 0
# 208 Train Loss 0.004324794 Test MSE 0 Test RE 0
# 209 Train Loss 0.004305633 Test MSE 0 Test RE 0
# 210 Train Loss 0.00429075 Test MSE 0 Test RE 0
# 211 Train Loss 0.0042759506 Test MSE 0 Test RE 0
# 212 Train Loss 0.004257201 Test MSE 0 Test RE 0
# 213 Train Loss 0.004239707 Test MSE 0 Test RE 0
# 214 Train Loss 0.0042270105 Test MSE 0 Test RE 0
# 215 Train Loss 0.0042107557 Test MSE 0 Test RE 0
# 216 Train Loss 0.004195368 Test MSE 0 Test RE 0
# 217 Train Loss 0.0041783736 Test MSE 0 Test RE 0
# 218 Train Loss 0.0041611465 Test MSE 0 Test RE 0
# 219 Train Loss 0.0041472185 Test MSE 0 Test RE 0
# 220 Train Loss 0.004130314 Test MSE 0 Test RE 0
# 221 Train Loss 0.004114273 Test MSE 0 Test RE 0
# 222 Train Loss 0.004099088 Test MSE 0 Test RE 0
# 223 Train Loss 0.004084338 Test MSE 0 Test RE 0
# 224 Train Loss 0.004072651 Test MSE 0 Test RE 0
# 225 Train Loss 0.0040596575 Test MSE 0 Test RE 0
# 226 Train Loss 0.0040447116 Test MSE 0 Test RE 0
# 227 Train Loss 0.0040311622 Test MSE 0 Test RE 0
# 228 Train Loss 0.0040184576 Test MSE 0 Test RE 0
# 229 Train Loss 0.0040065614 Test MSE 0 Test RE 0
# 230 Train Loss 0.0039951853 Test MSE 0 Test RE 0
# 231 Train Loss 0.0039818836 Test MSE 0 Test RE 0
# 232 Train Loss 0.0039667804 Test MSE 0 Test RE 0
# 233 Train Loss 0.003954028 Test MSE 0 Test RE 0
# 234 Train Loss 0.003940811 Test MSE 0 Test RE 0
# 235 Train Loss 0.0039283372 Test MSE 0 Test RE 0
# 236 Train Loss 0.0039156997 Test MSE 0 Test RE 0
# 237 Train Loss 0.0039054083 Test MSE 0 Test RE 0
# 238 Train Loss 0.0038920348 Test MSE 0 Test RE 0
# 239 Train Loss 0.0038779543 Test MSE 0 Test RE 0
# 240 Train Loss 0.0038641351 Test MSE 0 Test RE 0
# 241 Train Loss 0.0038515262 Test MSE 0 Test RE 0
# 242 Train Loss 0.003839542 Test MSE 0 Test RE 0
# 243 Train Loss 0.0038272198 Test MSE 0 Test RE 0
# 244 Train Loss 0.0038141452 Test MSE 0 Test RE 0
# 245 Train Loss 0.0038015186 Test MSE 0 Test RE 0
# 246 Train Loss 0.0037872111 Test MSE 0 Test RE 0
# 247 Train Loss 0.0037760416 Test MSE 0 Test RE 0
# 248 Train Loss 0.0037639318 Test MSE 0 Test RE 0
# 249 Train Loss 0.0037534905 Test MSE 0 Test RE 0
# 250 Train Loss 0.0037419647 Test MSE 0 Test RE 0
# 251 Train Loss 0.003730675 Test MSE 0 Test RE 0
# 252 Train Loss 0.0037222342 Test MSE 0 Test RE 0
# 253 Train Loss 0.0037114117 Test MSE 0 Test RE 0
# 254 Train Loss 0.0037024957 Test MSE 0 Test RE 0
# 255 Train Loss 0.0036919941 Test MSE 0 Test RE 0
# 256 Train Loss 0.00368361 Test MSE 0 Test RE 0
# 257 Train Loss 0.0036737488 Test MSE 0 Test RE 0
# 258 Train Loss 0.003664101 Test MSE 0 Test RE 0
# 259 Train Loss 0.0036559042 Test MSE 0 Test RE 0
# 260 Train Loss 0.003644028 Test MSE 0 Test RE 0
# 261 Train Loss 0.0036362095 Test MSE 0 Test RE 0
# 262 Train Loss 0.003627152 Test MSE 0 Test RE 0
# 263 Train Loss 0.0036158208 Test MSE 0 Test RE 0
# 264 Train Loss 0.0036063243 Test MSE 0 Test RE 0
# 265 Train Loss 0.0035967098 Test MSE 0 Test RE 0
# 266 Train Loss 0.0035884269 Test MSE 0 Test RE 0
# 267 Train Loss 0.0035785027 Test MSE 0 Test RE 0
# 268 Train Loss 0.0035682616 Test MSE 0 Test RE 0
# 269 Train Loss 0.00356001 Test MSE 0 Test RE 0
# 270 Train Loss 0.0035519437 Test MSE 0 Test RE 0
# 271 Train Loss 0.0035424228 Test MSE 0 Test RE 0
# 272 Train Loss 0.0035315608 Test MSE 0 Test RE 0
# 273 Train Loss 0.0035210056 Test MSE 0 Test RE 0
# 274 Train Loss 0.0035084607 Test MSE 0 Test RE 0
# 275 Train Loss 0.0035004115 Test MSE 0 Test RE 0
# 276 Train Loss 0.0034883441 Test MSE 0 Test RE 0
# 277 Train Loss 0.0034750577 Test MSE 0 Test RE 0
# 278 Train Loss 0.003463771 Test MSE 0 Test RE 0
# 279 Train Loss 0.003451645 Test MSE 0 Test RE 0
# 280 Train Loss 0.0034405799 Test MSE 0 Test RE 0
# 281 Train Loss 0.0034299495 Test MSE 0 Test RE 0
# 282 Train Loss 0.0034195506 Test MSE 0 Test RE 0
# 283 Train Loss 0.003409577 Test MSE 0 Test RE 0
# 284 Train Loss 0.0033998694 Test MSE 0 Test RE 0
# 285 Train Loss 0.0033907774 Test MSE 0 Test RE 0
# 286 Train Loss 0.0033817582 Test MSE 0 Test RE 0
# 287 Train Loss 0.0033726192 Test MSE 0 Test RE 0
# 288 Train Loss 0.0033647094 Test MSE 0 Test RE 0
# 289 Train Loss 0.0033560493 Test MSE 0 Test RE 0
# 290 Train Loss 0.0033471566 Test MSE 0 Test RE 0
# 291 Train Loss 0.0033388904 Test MSE 0 Test RE 0
# 292 Train Loss 0.0033305888 Test MSE 0 Test RE 0
# 293 Train Loss 0.003320897 Test MSE 0 Test RE 0
# 294 Train Loss 0.003312218 Test MSE 0 Test RE 0
# 295 Train Loss 0.003303475 Test MSE 0 Test RE 0
# 296 Train Loss 0.0032941601 Test MSE 0 Test RE 0
# 297 Train Loss 0.0032862679 Test MSE 0 Test RE 0
# 298 Train Loss 0.0032773875 Test MSE 0 Test RE 0
# 299 Train Loss 0.0032672433 Test MSE 0 Test RE 0
# 300 Train Loss 0.0032607736 Test MSE 0 Test RE 0
# 301 Train Loss 0.0032516501 Test MSE 0 Test RE 0
# 302 Train Loss 0.003245255 Test MSE 0 Test RE 0
# 303 Train Loss 0.003237288 Test MSE 0 Test RE 0
# 304 Train Loss 0.0032281533 Test MSE 0 Test RE 0
# 305 Train Loss 0.0032195663 Test MSE 0 Test RE 0
# 306 Train Loss 0.003211899 Test MSE 0 Test RE 0
# 307 Train Loss 0.0032030265 Test MSE 0 Test RE 0
# 308 Train Loss 0.0031946262 Test MSE 0 Test RE 0
# 309 Train Loss 0.003186808 Test MSE 0 Test RE 0
# 310 Train Loss 0.0031786473 Test MSE 0 Test RE 0
# 311 Train Loss 0.0031701464 Test MSE 0 Test RE 0
# 312 Train Loss 0.0031631335 Test MSE 0 Test RE 0
# 313 Train Loss 0.0031547693 Test MSE 0 Test RE 0
# 314 Train Loss 0.00314548 Test MSE 0 Test RE 0
# 315 Train Loss 0.0031364395 Test MSE 0 Test RE 0
# 316 Train Loss 0.0031280278 Test MSE 0 Test RE 0
# 317 Train Loss 0.0031212284 Test MSE 0 Test RE 0
# 318 Train Loss 0.003111451 Test MSE 0 Test RE 0
# 319 Train Loss 0.0031017372 Test MSE 0 Test RE 0
# 320 Train Loss 0.0030935034 Test MSE 0 Test RE 0
# 321 Train Loss 0.003084702 Test MSE 0 Test RE 0
# 322 Train Loss 0.003075794 Test MSE 0 Test RE 0
# 323 Train Loss 0.0030664466 Test MSE 0 Test RE 0
# 324 Train Loss 0.0030590005 Test MSE 0 Test RE 0
# 325 Train Loss 0.0030509622 Test MSE 0 Test RE 0
# 326 Train Loss 0.0030421102 Test MSE 0 Test RE 0
# 327 Train Loss 0.0030341323 Test MSE 0 Test RE 0
# 328 Train Loss 0.003027979 Test MSE 0 Test RE 0
# 329 Train Loss 0.003019965 Test MSE 0 Test RE 0
# 330 Train Loss 0.0030108152 Test MSE 0 Test RE 0
# 331 Train Loss 0.0030049132 Test MSE 0 Test RE 0
# 332 Train Loss 0.0029968496 Test MSE 0 Test RE 0
# 333 Train Loss 0.0029895196 Test MSE 0 Test RE 0
# 334 Train Loss 0.0029810958 Test MSE 0 Test RE 0
# 335 Train Loss 0.002970681 Test MSE 0 Test RE 0
# 336 Train Loss 0.0029633737 Test MSE 0 Test RE 0
# 337 Train Loss 0.0029558213 Test MSE 0 Test RE 0
# 338 Train Loss 0.0029489228 Test MSE 0 Test RE 0
# 339 Train Loss 0.0029405113 Test MSE 0 Test RE 0
# 340 Train Loss 0.0029313904 Test MSE 0 Test RE 0
# 341 Train Loss 0.0029238467 Test MSE 0 Test RE 0
# 342 Train Loss 0.0029178418 Test MSE 0 Test RE 0
# 343 Train Loss 0.0029109498 Test MSE 0 Test RE 0
# 344 Train Loss 0.0029047416 Test MSE 0 Test RE 0
# 345 Train Loss 0.0028977261 Test MSE 0 Test RE 0
# 346 Train Loss 0.002889688 Test MSE 0 Test RE 0
# 347 Train Loss 0.002884011 Test MSE 0 Test RE 0
# 348 Train Loss 0.0028782974 Test MSE 0 Test RE 0
# 349 Train Loss 0.002872542 Test MSE 0 Test RE 0
# 350 Train Loss 0.0028657974 Test MSE 0 Test RE 0
# 351 Train Loss 0.0028587757 Test MSE 0 Test RE 0
# 352 Train Loss 0.0028530108 Test MSE 0 Test RE 0
# 353 Train Loss 0.0028458266 Test MSE 0 Test RE 0
# 354 Train Loss 0.0028398782 Test MSE 0 Test RE 0
# 355 Train Loss 0.0028337822 Test MSE 0 Test RE 0
# 356 Train Loss 0.0028280434 Test MSE 0 Test RE 0
# 357 Train Loss 0.0028228124 Test MSE 0 Test RE 0
# 358 Train Loss 0.0028157097 Test MSE 0 Test RE 0
# 359 Train Loss 0.002810099 Test MSE 0 Test RE 0
# 360 Train Loss 0.0028032002 Test MSE 0 Test RE 0
# 361 Train Loss 0.0027972818 Test MSE 0 Test RE 0
# 362 Train Loss 0.0027911554 Test MSE 0 Test RE 0
# 363 Train Loss 0.0027841676 Test MSE 0 Test RE 0
# 364 Train Loss 0.0027783085 Test MSE 0 Test RE 0
# 365 Train Loss 0.0027702516 Test MSE 0 Test RE 0
# 366 Train Loss 0.0027639074 Test MSE 0 Test RE 0
# 367 Train Loss 0.0027573681 Test MSE 0 Test RE 0
# 368 Train Loss 0.0027497695 Test MSE 0 Test RE 0
# 369 Train Loss 0.0027441373 Test MSE 0 Test RE 0
# 370 Train Loss 0.0027383266 Test MSE 0 Test RE 0
# 371 Train Loss 0.0027328369 Test MSE 0 Test RE 0
# 372 Train Loss 0.0027277286 Test MSE 0 Test RE 0
# 373 Train Loss 0.0027220182 Test MSE 0 Test RE 0
# 374 Train Loss 0.0027150733 Test MSE 0 Test RE 0
# 375 Train Loss 0.0027087305 Test MSE 0 Test RE 0
# 376 Train Loss 0.002702908 Test MSE 0 Test RE 0
# 377 Train Loss 0.0026982874 Test MSE 0 Test RE 0
# 378 Train Loss 0.002691218 Test MSE 0 Test RE 0
# 379 Train Loss 0.0026828127 Test MSE 0 Test RE 0
# 380 Train Loss 0.0026751803 Test MSE 0 Test RE 0
# 381 Train Loss 0.0026690117 Test MSE 0 Test RE 0
# 382 Train Loss 0.0026638384 Test MSE 0 Test RE 0
# 383 Train Loss 0.0026574638 Test MSE 0 Test RE 0
# 384 Train Loss 0.002650493 Test MSE 0 Test RE 0
# 385 Train Loss 0.0026454942 Test MSE 0 Test RE 0
# 386 Train Loss 0.0026397011 Test MSE 0 Test RE 0
# 387 Train Loss 0.0026354794 Test MSE 0 Test RE 0
# 388 Train Loss 0.0026296242 Test MSE 0 Test RE 0
# 389 Train Loss 0.0026232768 Test MSE 0 Test RE 0
# 390 Train Loss 0.0026169263 Test MSE 0 Test RE 0
# 391 Train Loss 0.0026111777 Test MSE 0 Test RE 0
# 392 Train Loss 0.0026054182 Test MSE 0 Test RE 0
# 393 Train Loss 0.0026004887 Test MSE 0 Test RE 0
# 394 Train Loss 0.002595425 Test MSE 0 Test RE 0
# 395 Train Loss 0.0025892244 Test MSE 0 Test RE 0
# 396 Train Loss 0.0025840944 Test MSE 0 Test RE 0
# 397 Train Loss 0.0025805545 Test MSE 0 Test RE 0
# 398 Train Loss 0.0025750985 Test MSE 0 Test RE 0
# 399 Train Loss 0.0025695846 Test MSE 0 Test RE 0
# 400 Train Loss 0.0025631315 Test MSE 0 Test RE 0
# 401 Train Loss 0.0025564316 Test MSE 0 Test RE 0
# 402 Train Loss 0.0025512984 Test MSE 0 Test RE 0
# 403 Train Loss 0.002546577 Test MSE 0 Test RE 0
# 404 Train Loss 0.0025425542 Test MSE 0 Test RE 0
# 405 Train Loss 0.002536708 Test MSE 0 Test RE 0
# 406 Train Loss 0.0025315988 Test MSE 0 Test RE 0
# 407 Train Loss 0.0025268337 Test MSE 0 Test RE 0
# 408 Train Loss 0.0025209854 Test MSE 0 Test RE 0
# 409 Train Loss 0.0025170066 Test MSE 0 Test RE 0
# 410 Train Loss 0.0025121067 Test MSE 0 Test RE 0
# 411 Train Loss 0.0025071513 Test MSE 0 Test RE 0
# 412 Train Loss 0.002502296 Test MSE 0 Test RE 0
# 413 Train Loss 0.002498107 Test MSE 0 Test RE 0
# 414 Train Loss 0.0024933054 Test MSE 0 Test RE 0
# 415 Train Loss 0.002487752 Test MSE 0 Test RE 0
# 416 Train Loss 0.0024811777 Test MSE 0 Test RE 0
# 417 Train Loss 0.0024759953 Test MSE 0 Test RE 0
# 418 Train Loss 0.0024710384 Test MSE 0 Test RE 0
# 419 Train Loss 0.0024662446 Test MSE 0 Test RE 0
# 420 Train Loss 0.002461263 Test MSE 0 Test RE 0
# 421 Train Loss 0.0024564052 Test MSE 0 Test RE 0
# 422 Train Loss 0.0024512438 Test MSE 0 Test RE 0
# 423 Train Loss 0.002447136 Test MSE 0 Test RE 0
# 424 Train Loss 0.0024421324 Test MSE 0 Test RE 0
# 425 Train Loss 0.0024373857 Test MSE 0 Test RE 0
# 426 Train Loss 0.002431397 Test MSE 0 Test RE 0
# 427 Train Loss 0.0024259235 Test MSE 0 Test RE 0
# 428 Train Loss 0.0024219907 Test MSE 0 Test RE 0
# 429 Train Loss 0.0024168289 Test MSE 0 Test RE 0
# 430 Train Loss 0.0024124184 Test MSE 0 Test RE 0
# 431 Train Loss 0.00240773 Test MSE 0 Test RE 0
# 432 Train Loss 0.0024019722 Test MSE 0 Test RE 0
# 433 Train Loss 0.0023966026 Test MSE 0 Test RE 0
# 434 Train Loss 0.0023928152 Test MSE 0 Test RE 0
# 435 Train Loss 0.0023873053 Test MSE 0 Test RE 0
# 436 Train Loss 0.0023821187 Test MSE 0 Test RE 0
# 437 Train Loss 0.0023753997 Test MSE 0 Test RE 0
# 438 Train Loss 0.0023709042 Test MSE 0 Test RE 0
# 439 Train Loss 0.002367222 Test MSE 0 Test RE 0
# 440 Train Loss 0.0023627665 Test MSE 0 Test RE 0
# 441 Train Loss 0.0023582757 Test MSE 0 Test RE 0
# 442 Train Loss 0.0023531062 Test MSE 0 Test RE 0
# 443 Train Loss 0.0023491129 Test MSE 0 Test RE 0
# 444 Train Loss 0.0023451946 Test MSE 0 Test RE 0
# 445 Train Loss 0.0023405803 Test MSE 0 Test RE 0
# 446 Train Loss 0.0023360867 Test MSE 0 Test RE 0
# 447 Train Loss 0.0023312345 Test MSE 0 Test RE 0
# 448 Train Loss 0.0023263888 Test MSE 0 Test RE 0
# 449 Train Loss 0.0023220167 Test MSE 0 Test RE 0
# 450 Train Loss 0.0023177117 Test MSE 0 Test RE 0
# 451 Train Loss 0.0023131142 Test MSE 0 Test RE 0
# 452 Train Loss 0.0023080427 Test MSE 0 Test RE 0
# 453 Train Loss 0.0023030988 Test MSE 0 Test RE 0
# 454 Train Loss 0.0022980997 Test MSE 0 Test RE 0
# 455 Train Loss 0.0022933497 Test MSE 0 Test RE 0
# 456 Train Loss 0.0022889276 Test MSE 0 Test RE 0
# 457 Train Loss 0.0022843769 Test MSE 0 Test RE 0
# 458 Train Loss 0.0022795335 Test MSE 0 Test RE 0
# 459 Train Loss 0.002275057 Test MSE 0 Test RE 0
# 460 Train Loss 0.0022713277 Test MSE 0 Test RE 0
# 461 Train Loss 0.0022666967 Test MSE 0 Test RE 0
# 462 Train Loss 0.0022625476 Test MSE 0 Test RE 0
# 463 Train Loss 0.0022589094 Test MSE 0 Test RE 0
# 464 Train Loss 0.0022542798 Test MSE 0 Test RE 0
# 465 Train Loss 0.0022511787 Test MSE 0 Test RE 0
# 466 Train Loss 0.0022480562 Test MSE 0 Test RE 0
# 467 Train Loss 0.0022436653 Test MSE 0 Test RE 0
# 468 Train Loss 0.0022391446 Test MSE 0 Test RE 0
# 469 Train Loss 0.0022348077 Test MSE 0 Test RE 0
# 470 Train Loss 0.0022314559 Test MSE 0 Test RE 0
# 471 Train Loss 0.0022278673 Test MSE 0 Test RE 0
# 472 Train Loss 0.0022235783 Test MSE 0 Test RE 0
# 473 Train Loss 0.002218966 Test MSE 0 Test RE 0
# 474 Train Loss 0.0022151126 Test MSE 0 Test RE 0
# 475 Train Loss 0.0022117067 Test MSE 0 Test RE 0
# 476 Train Loss 0.0022086697 Test MSE 0 Test RE 0
# 477 Train Loss 0.002204746 Test MSE 0 Test RE 0
# 478 Train Loss 0.0021998016 Test MSE 0 Test RE 0
# 479 Train Loss 0.0021957604 Test MSE 0 Test RE 0
# 480 Train Loss 0.0021918237 Test MSE 0 Test RE 0
# 481 Train Loss 0.002188856 Test MSE 0 Test RE 0
# 482 Train Loss 0.0021851948 Test MSE 0 Test RE 0
# 483 Train Loss 0.0021808078 Test MSE 0 Test RE 0
# 484 Train Loss 0.0021770822 Test MSE 0 Test RE 0
# 485 Train Loss 0.0021736696 Test MSE 0 Test RE 0
# 486 Train Loss 0.0021705574 Test MSE 0 Test RE 0
# 487 Train Loss 0.0021672917 Test MSE 0 Test RE 0
# 488 Train Loss 0.0021626928 Test MSE 0 Test RE 0
# 489 Train Loss 0.002157823 Test MSE 0 Test RE 0
# 490 Train Loss 0.0021539526 Test MSE 0 Test RE 0
# 491 Train Loss 0.0021497312 Test MSE 0 Test RE 0
# 492 Train Loss 0.0021459493 Test MSE 0 Test RE 0
# 493 Train Loss 0.0021411967 Test MSE 0 Test RE 0
# 494 Train Loss 0.0021369166 Test MSE 0 Test RE 0
# 495 Train Loss 0.0021330772 Test MSE 0 Test RE 0
# 496 Train Loss 0.0021296488 Test MSE 0 Test RE 0
# 497 Train Loss 0.0021262506 Test MSE 0 Test RE 0
# 498 Train Loss 0.0021225181 Test MSE 0 Test RE 0
# 499 Train Loss 0.0021180012 Test MSE 0 Test RE 0
# Training time: 1349.29

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

count_parameters(PINN)
# Out:
# 41603

# %%
# nan_flag = train_model(max_iter,reps)

# %%
uvp_pred = PINN.forward(xyt_test_tensor).cpu().detach().numpy()

# %%
u_pred = uvp_pred[:,0].reshape(101,101,101)
v_pred = uvp_pred[:,1].reshape(101,101,101)

a = 10
b = 10
fig,axs = plt.subplots(3,2)

frame_idx = 19

ax = axs[0,0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=0.2s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[0,1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=0.2s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

#--------------------------------------------------------------------------------------------------------
frame_idx = 59

ax = axs[1,0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=0.6s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[1,1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=0.6s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

fig.subplots_adjust(wspace = 0.7)


#--------------------------------------------------------------------------------------------------------
frame_idx = 99

ax = axs[2,0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[2,1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[frame_idx,:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

fig.subplots_adjust(wspace = 0.1,hspace = 0.4)
# plt.savefig('NS_lid.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)

# %%
fig, ax = plt.subplots()
frame_idx = 99
ax.figure.set_size_inches(a,b)
psi = np.sqrt(np.square(v_pred[frame_idx,:,:]) + np.square(u_pred[frame_idx,:,:])) 
img = ax.imshow(np.flip(np.transpose(psi),axis =0),cmap = 'jet',extent= [0,1,0,1],vmax = 5,vmin = 0)
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

# plt.savefig('NS_lid.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)
# Out:
# (0.0, 1.0)

# %%
u_matlab = loadmat("uv_matlab.mat")['u']
v_matlab = loadmat("uv_matlab.mat")['v']

frame_idx = 100
fig,axs = plt.subplots(1,2)
a = 10
b = 3

fig.set_size_inches(a,b)

ax = axs[0]
ax.plot(y,u_matlab[50,:],'b-.',label = 'SOR')
ax.plot(y,u_pred[frame_idx,50,:],'r',label = 'PINN')
ax.set_xlim([0,1])
ax.legend()
ax.set_xlabel('$y$')
ax.set_ylabel('$u(x=0.5)$')
ax.set_title('Velocity in $x$-direction') 

ax = axs[1]
ax.plot(x,v_matlab[:,50],'b-.',label = 'SOR')
ax.plot(x,v_pred[frame_idx,:,50],'r',label = 'PINN')
ax.set_xlim([0,1])
ax.legend(loc = 1)
ax.set_xlabel('$x$')
ax.set_ylabel('$v(y=0.5)$')
ax.set_title('Velocity in $y$-direction') 

fig.subplots_adjust(wspace = 0.4)
# plt.savefig('SOR_PINN.svg', format='svg',bbox_inches = 'tight')

# %%
u_pred = u_matlab
v_pred = v_matlab

a = 10
b = 10
fig,axs = plt.subplots(1,2)

frame_idx = 99

ax = axs[0]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(u_pred[:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1],vmin = np.min(u_pred),vmax = np.max(u_pred))
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10,fraction=0.08)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$u (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])


#-------------------------------------------------------------------

ax = axs[1]
ax.figure.set_size_inches(a,b)
img = ax.imshow(np.flip(np.transpose(v_pred[:,:]),axis =0),cmap = 'jet',extent= [0,1,0,1])
# fig.colorbar(img)
cbar = fig.colorbar(img, ax=ax,aspect = 10,fraction=0.08)

ax.set_xlabel('x',fontsize = 14)
ax.set_ylabel('y',fontsize = 14)

ax.set_title("$v (t=1.0s)$",fontsize = 12)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

fig.subplots_adjust(wspace = 0.3)

# plt.savefig('NS_lid_SOR.svg', format='svg',pad_inches=0, bbox_inches='tight',transparent=True)

# %%
X, Y = np.meshgrid(np.linspace(0, 1, 101), np.linspace(0, 1, 101))
u = u_pred[frame_idx,:,:]  # Replace with your u values
v = v_pred[frame_idx,:,:]  # Replace with your v values
xstart =np.random.uniform()
ystart = np.random.uniform()  # Replace with your starting points
L = 1  # Replace with the desired value for L

# Create the streamline plot
# fig = plt.figure(3)
h = plt.streamplot(X, Y, u.T, v.T, start_points=np.column_stack([xstart, ystart]), color='k',linewidth=1.5, density=0.1, arrowstyle='->', arrowsize=1.5)
plt.title('Stream Function')
plt.xlabel('x-location')
plt.ylabel('y-location')
# plt.axis('equal', [0,1, 0, 1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 X, Y = np.meshgrid(np.linspace(0, 1, 101), np.linspace(0, 1, 101))
# ----> 2 u = u_pred[frame_idx,:,:]  # Replace with your u values
#       3 v = v_pred[frame_idx,:,:]  # Replace with your v values
#       4 xstart =np.random.uniform()
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

count_parameters(PINN)

# %%
p_pred = uvp_pred[:,2].reshape(100,100,100)
fig,ax = plt.subplots()
img = ax.imshow(np.flip(np.transpose(p_pred[99,:,:]),axis =0),cmap = 'jet')
fig.colorbar(img)
