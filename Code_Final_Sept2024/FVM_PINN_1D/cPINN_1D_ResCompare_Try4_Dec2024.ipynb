# %%
import torch
      # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec
# from mpl_toolkits.axes_grid1 import make_axes_locatable
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.ticker


import numpy as np
import time
# from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

from FVM_1D_Robin import fvm_1D
from coPINN_1D import coPINN_1D_Solver
from Residuals import res_compare

from Plot_1D_Solutions import save_imshow_sidebyside

import matplotlib.pyplot as plt

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:3

# %%
#Code partially from ChatGPT
# dT/dt = alpha*d^2T/dx^2 + beta*C
# dC/dt = D*d^2T/dx^2 + gamma*C
#T(0,t)=T(L,t)=0,C(0,t)=C(L,t)=0 Boundaries #Sometimes I change
#Initial T(x,0)=f(x),C(x,0)=g(x)

torch.pi = torch.acos(torch.zeros(1)).item() * 2

def initial_TC(x):
    # T_init = np.array(x<0.5,dtype = 'int')
    # C_init = np.array(x>0.5,dtype = 'int')

    T_init = 0.0*x
    # C_init = 1.0 + 0.0*x
    C_init = np.sin(4*np.pi*x)

    # T_init = np.sin(np.)

    return T_init,C_init

def boundary_TC(x):
    T1 = 0
    T2 = 0
    C1 = 0
    C2 = 0

    return T1,T2,C1,C2

def forcing_func(x):

    return np.sin(2*np.pi*x)

def forcing_func_torch(x):

    return torch.sin(2*torch.pi*x)

# %%
t_end = 1


L = 1.0            # Length of the rod
          # Number of cells
      
alpha = 0.01       # Thermal diffusivity
D = 0.01           # Diffusion coefficient
beta = 1.0         # Coupling coefficient for temperature
gamma = 1.0        # Coupling coefficient for concentration

pde_related_funcs = {'initial_condition':initial_TC,"boundary_conditions":boundary_TC,
                     "forcing_function":forcing_func,"forcing_function_torch":forcing_func_torch}

problem_constants = {"L":L,"Max_time":t_end,"alpha":alpha,"beta":beta,"gamma":gamma,"D":D}

# %%
# Parameters
N_x_1 = 20
t_steps_1 = 1001

T_FVM_1, C_FVM_1 = fvm_1D(pde_related_funcs,problem_constants,N_x_1,t_steps_1)


T_FVM_norm_1 = np.linalg.norm(T_FVM_1,2)
C_FVM_norm_1 = np.linalg.norm(C_FVM_1,2)

fvm_results_1 = {'T_FVM': T_FVM_1,'C_FVM':C_FVM_1,"T_FVM_norm":T_FVM_norm_1,"C_FVM_norm":C_FVM_norm_1}
# Out:
# Elapsed Time 0.294448

# %%
# Parameters
N_x_2 = 200
t_steps_2 = 1001

T_FVM_2, C_FVM_2 = fvm_1D(pde_related_funcs,problem_constants,N_x_2,t_steps_2)


T_FVM_norm_2 = np.linalg.norm(T_FVM_2,2)
C_FVM_norm_2 = np.linalg.norm(C_FVM_2,2)

fvm_results_2 = {'T_FVM': T_FVM_2,'C_FVM':C_FVM_2,"T_FVM_norm":T_FVM_norm_2,"C_FVM_norm":C_FVM_norm_2}
# Out:
# Elapsed Time 0.488496

# %%
optimizer_algo = "LBFGS" #or Adam
max_iter = 100 #200

N_T = 2000 #Total number of data points for 'y'
N_f = 10000 #Total number of collocation points 

layers1 = np.array([2,50,50,50,50,1]) #9 hidden layers
layers2 = np.array([2,50,50,50,50,1]) #9 hidden layers

coPINN_constants = {"N_T":N_T,"N_f":N_f,"max_iter" :max_iter,"layers1":layers1,"layers2":layers2,
                    "optimizer_algo":optimizer_algo,"device":device,"fvm_results":fvm_results_2}

# %%
coPINN_solver = coPINN_1D_Solver(coPINN_constants,pde_related_funcs,problem_constants,N_x_2,t_steps_2)
coPINN_trained = coPINN_solver.train_model(1)
# Out:
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears1): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1-3): 3 x Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=1, bias=True)
#   )
#   (linears2): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1-3): 3 x Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# 1
# 0 Train Loss
# 37 Train Loss 1.7401475e-05 RD T: 0.5436787654217828 RD C: 0.11589929060943675
# 38 Train Loss 1.6555052e-05 RD T: 0.5435513779738341 RD C: 0.11572866820107079
# 39 Train Loss 1.5770134e-05 RD T: 0.5436049457999504 RD C: 0.115623668605058
# 40 Train Loss 1.5149861e-05 RD T: 0.5436001317689194 RD C: 0.11574539450021702
# 41 Train Loss 1.43918305e-05 RD T: 0.5436111387279917 RD C: 0.11572593187005986
# 42 Train Loss 1.3513965e-05 RD T: 0.5435478643244921 RD C: 0.11560239449904317
# 43 Train Loss 1.2898194e-05 RD T: 0.5437498393527966 RD C: 0.11568895293490969
# 44 Train Loss 1.2131899e-05 RD T: 0.5437031205956994 RD C: 0.11570457784759852
# 45 Train Loss 1.1845699e-05 RD T: 0.5438198221512445 RD C: 0.11582705242723611
# 46 Train Loss 1.09918865e-05 RD T: 0.5438693146978204 RD C: 0.11594595307850031
# 47 Train Loss 1.0529258e-05 RD T: 0.5437506895823557 RD C: 0.11577631351917617
# 48 Train Loss 9.787576e-06 RD T: 0.5437925571454825 RD C: 0.1157896590223338
# 49 Train Loss 9.520887e-06 RD T: 0.5438186848368065 RD C: 0.11592376774325323
# 50 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 51 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 52 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 53 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 54 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 55 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 56 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 57 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 58 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 59 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 60 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 61 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 62 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 63 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 64 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 65 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 66 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 67 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 68 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 69 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 70 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 71 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 72 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 73 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 74 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 75 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 76 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 77 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 78 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 79 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 80 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 81 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 82 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 83 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 84 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 85 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 86 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 87 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 88 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 89 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 90 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 91 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 92 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 93 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 94 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 95 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 96 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 97 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 98 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# 99 Train Loss 9.505726e-06 RD T: 0.5438260263604336 RD C: 0.11591024170630479
# Training time: 52.22

# %%
T_PINN,C_PINN = coPINN_trained.test()
s = T_FVM_2.shape
T_PINN = T_PINN.reshape(s[0],s[1])
C_PINN = C_PINN.reshape(s[0],s[1])

# %%
plt.plot(T_PINN[:,0])
plt.plot(T_FVM_2[:,0])

# %%
# print("T1 RMSD",np.sqrt(np.mean(np.square(T_FVM_1 - T_PINN))))
# print("C1 RMSD",np.sqrt(np.mean(np.square(C_FVM_1 - C_PINN))))

print("T2 RMSD",np.sqrt(np.mean(np.square(T_FVM_2 - T_PINN))))
print("C2 RMSD",np.sqrt(np.mean(np.square(C_FVM_2 - C_PINN))))
# Out:
# T2 RMSD 0.26974600347039807
# C2 RMSD 0.049163199840258714

# %%
fixed_params = {'xlabel': '$t$','ylabel': '$x$','extent': [0,L,0,t_end],
                'proposed_indicator': 2,'aspect':1}

data = [T_FVM_1,T_FVM_2,T_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Temperature $T(x,t)$'
save_name = "Temp_1D_Values"
vmax = np.max(T_PINN)
vmin = np.min(T_PINN)


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
data = [C_FVM_1,C_FVM_2,C_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Concentration $C(x,t)$'
save_name = "Conc_1D_Values"
vmax = np.max(C_PINN)
vmin = np.min(C_PINN)


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
opt = 'neutral'
interp_method = 'spline'

interp_layers = [2,50,50,50,50,1]
interp_device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
interp_max_iter = 5000

NN_constants = {"layers":interp_layers,"device":interp_device,"max_iter":interp_max_iter}



f1_PINN,f1_fvm_1,f2_PINN,f2_fvm_1 = res_compare(opt,interp_method,pde_related_funcs,problem_constants,
                                            N_x_2, t_steps_2,N_x_1,t_steps_1,T_FVM_1,C_FVM_1,coPINN_trained,device,
                                            NN_interp_constants=NN_constants)

f1_PINN,f1_fvm_2,f2_PINN,f2_fvm_2 = res_compare(opt,interp_method,pde_related_funcs,problem_constants,
                                            N_x_2, t_steps_2,N_x_2,t_steps_2,T_FVM_2,C_FVM_2,coPINN_trained,device,
                                            NN_interp_constants=NN_constants)
# Out:
# (200, 1001)
# (200, 1001)
# (200, 1001)
# PINN_f1: 0.0018
# FVM_f1: 0.0230
# PINN_f2: 0.0015
# FVM_f2: 0.0443
# (200, 1001)
# (200, 1001)
# (200, 1001)
# PINN_f1: 0.0018
# FVM_f1: 0.0024
# PINN_f2: 0.0015
# FVM_f2: 0.0068

# %%
problem_constants
# Out:
# {'L': 1.0,
#  'Max_time': 1,
#  'alpha': 0.01,
#  'beta': 1.0,
#  'gamma': 1.0,
#  'D': 0.01,
#  'forcing_func_torch': <function __main__.forcing_func_torch(x)>}

# %%
data = [f1_fvm_1,f1_fvm_2,f1_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Residual $f_h(x,t)$'
save_name = "Residuals_HeatEquation"
vmax = np.max(np.abs(f1_fvm_1))
vmin = 0


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
data = [f2_fvm_1,f2_fvm_2,f2_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Residuals $f_d(x,t)$'
save_name = "Residuals_DiffusionEquation"
# vmax = np.max(np.abs(f2_fvm))
vmax = 0.05
vmin = 0


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
loss_thresh = 25000
level = "_low"
label = "Burgers_coPINN_" 

x = np.linspace(0,1,N_x).reshape(-1,1)
t = np.linspace(0,t_max,t_steps).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

lb_xt = xt[0]
ub_xt = xt[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 level = "_low"
#       3 label = "Burgers_coPINN_"
# ----> 5 x = np.linspace(0,1,N_x).reshape(-1,1)
#       6 t = np.linspace(0,t_max,t_steps).reshape(-1,1)
#       8 X,T = np.meshgrid(x,t)
#
# NameError: name 'N_x' is not defined

# %%
pi = torch.from_numpy(np.array(np.pi)).double().to(device)


x = np.linspace(0,1,N_x)
t = np.linspace(0,t_max,t_steps)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

# %%
#CHECKING RESIDUALS AND PLOTTING
#f2 = dC_dt - D*d2C_dx2 - gamma*T

# %%
#CHECKING RESIDUALS AND PLOTTING ~  GRID POINTS
f1_PINN,f1_FVM,f2_PINN,f2_FVM = res_compare('grid')
# Out:
# PINN_f1: 0.0019
# FVM_f1: 0.0069
# PINN_f2: 0.0014
# FVM_f2: 0.1048

# %%
np.mean(f2_FVM)
# Out:
# 5.4337797442834806e-15

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet
fig.tight_layout()



ax = axs[0]
img = ax.imshow(np.abs(f1_PINN),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.03)
ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


ax = axs[1]
img = ax.imshow(np.abs(f1_FVM),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.03)
ax.set_title('FVM $u(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


fig.tight_layout()
# plt.savefig('Burgers_test_u.svg',format = 'svg')
# plt.savefig('FSU_Burgers_test_u.svg',format = 'svg',bbox_inches = 'tight')

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet
fig.tight_layout()



ax = axs[0]
img = ax.imshow(np.abs(f2_PINN),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.01)
ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


ax = axs[1]
img = ax.imshow(np.abs(f2_FVM),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.01)
ax.set_title('FVM $u(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


fig.tight_layout()

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet
fig.tight_layout()



ax = axs[0]
img = ax.imshow(T_PINN_matrix,interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


ax = axs[1]
img = ax.imshow(T_FVM_matrix,interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('FVM $u(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


fig.tight_layout()
# plt.savefig('Burgers_test_u.svg',format = 'svg')
# plt.savefig('FSU_Burgers_test_u.svg',format = 'svg',bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       3 fig.tight_layout()
#       7 ax = axs[0]
# ----> 8 img = ax.imshow(T_PINN_matrix,interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
#       9 ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
#      10 ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
#
# NameError: name 'T_PINN_matrix' is not defined

# %%
plt.plot(T_FVM_matrix[:,100],'b')
plt.plot(T_PINN_matrix[:,100],'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plt.plot(T_FVM_matrix[:,100],'b')
#       2 plt.plot(T_PINN_matrix[:,100],'r')
#
# NameError: name 'T_FVM_matrix' is not defined

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet



ax = axs[0]
img = ax.imshow(C_PINN_matrix,cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('PINN $T(x,t)$',math_fontfamily = 'cm', color = 'r',fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)
fig.tight_layout()


ax = axs[1]
img = ax.imshow(C_FVM_matrix,cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('FVM $T(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 12)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 12)


fig.tight_layout()
# plt.savefig('Burgers_test_T.svg',format = 'svg')
# plt.savefig('FSU_Burgers_test_T.svg',format = 'svg',bbox_inches = 'tight')
