# %%
import torch
      # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec
# from mpl_toolkits.axes_grid1 import make_axes_locatable
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.ticker


import numpy as np
import time
# from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io
from scipy.io import savemat

from smt.sampling_methods import LHS

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

from FVM_1D import fvm_1D
from coPINN_1D import coPINN_1D_Solver
from Residuals import res_compare

from Plot_1D_Solutions import save_imshow_sidebyside

import matplotlib.pyplot as plt

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda:3

# %%
#Code partially from ChatGPT
# dT/dt = alpha*d^2T/dx^2 + beta*C
# dC/dt = D*d^2T/dx^2 + gamma*C
#T(0,t)=T(L,t)=0,C(0,t)=C(L,t)=0 Boundaries #Sometimes I change
#Initial T(x,0)=f(x),C(x,0)=g(x)

torch.pi = torch.acos(torch.zeros(1)).item() * 2

def initial_TC(x):
    # T_init = np.array(x<0.5,dtype = 'int')
    # C_init = np.array(x>0.5,dtype = 'int')

    T_init = 0.0*x
    # C_init = 1.0 + 0.0*x
    C_init = np.sin(2*np.pi*x)

    # T_init = np.sin(np.)

    return T_init,C_init

def boundary_TC(x):
    T1 = 0
    T2 = 0
    C1 = 0
    C2 = 0

    return T1,T2,C1,C2

def forcing_func(x):

    return np.sin(2*np.pi*x)

def forcing_func_torch(x):

    return torch.sin(2*torch.pi*x)

# %%
t_end = 1


L = 1.0            # Length of the rod
          # Number of cells
      
alpha = 0.01       # Thermal diffusivity
D = 0.01           # Diffusion coefficient
beta = 1.0         # Coupling coefficient for temperature
gamma = 1.0        # Coupling coefficient for concentration

pde_related_funcs = {'initial_condition':initial_TC,"boundary_conditions":boundary_TC,
                     "forcing_function":forcing_func,"forcing_function_torch":forcing_func_torch}

problem_constants = {"L":L,"Max_time":t_end,"alpha":alpha,"beta":beta,"gamma":gamma,"D":D}

# %%
# Parameters
N_x_1 = 20
t_steps_1 = 1001

T_FVM_1, C_FVM_1 = fvm_1D(pde_related_funcs,problem_constants,N_x_1,t_steps_1)


T_FVM_norm_1 = np.linalg.norm(T_FVM_1,2)
C_FVM_norm_1 = np.linalg.norm(C_FVM_1,2)

fvm_results_1 = {'T_FVM': T_FVM_1,'C_FVM':C_FVM_1,"T_FVM_norm":T_FVM_norm_1,"C_FVM_norm":C_FVM_norm_1}
# Out:
# Elapsed Time 0.296733

# %%
# Parameters
N_x_2 = 200
t_steps_2 = 1001

T_FVM_2, C_FVM_2 = fvm_1D(pde_related_funcs,problem_constants,N_x_2,t_steps_2)


T_FVM_norm_2 = np.linalg.norm(T_FVM_2,2)
C_FVM_norm_2 = np.linalg.norm(C_FVM_2,2)

fvm_results_2 = {'T_FVM': T_FVM_2,'C_FVM':C_FVM_2,"T_FVM_norm":T_FVM_norm_2,"C_FVM_norm":C_FVM_norm_2}
# Out:
# Elapsed Time 0.474413

# %%
optimizer_algo = "LBFGS" #or Adam
max_iter = 100 #200

N_T = 2000 #Total number of data points for 'y'
N_f = 10000 #Total number of collocation points 

layers1 = np.array([2,50,50,50,50,1]) #9 hidden layers
layers2 = np.array([2,50,50,50,50,1]) #9 hidden layers

coPINN_constants = {"N_T":N_T,"N_f":N_f,"max_iter" :max_iter,"layers1":layers1,"layers2":layers2,
                    "optimizer_algo":optimizer_algo,"device":device,"fvm_results":fvm_results_2}

# %%
coPINN_solver = coPINN_1D_Solver(coPINN_constants,pde_related_funcs,problem_constants,N_x_2,t_steps_2)
coPINN_trained = coPINN_solver.train_model(1)
# Out:
# Sequentialmodel(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears1): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1-3): 3 x Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=1, bias=True)
#   )
#   (linears2): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1-3): 3 x Linear(in_features=50, out_features=50, bias=True)
#     (4): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# 1
# 0 Train Loss 0.19894086 RD T: 0.6927908815609718 RD C: 0.9333156812281755
# 1 Train Loss 0.09135138 RD T: 0.24419883943133236 RD C: 0.4452282624359654
# 2 Train Loss 0.012969345 RD T: 0.10031974664823114 RD C: 0.10706810610637442
# 3 Train Loss 0.00244265 RD T: 0.05800103437407493 RD C: 0.040914619798862545
# 4 Train Loss 0.0009550142 RD T: 0.050657093855403984 RD C: 0.024400106159027605
# 5 Train Loss 0.00048014757 RD T: 0.05094307132974183 RD C: 0.024770729174389067
# 6 Train Loss 0.00031187152 RD T: 0.04966892414811828 RD C: 0.023068692847328248
# 7 Train Loss 0.0001742573 RD T: 0.049968046299719154 RD C: 0.02386035024027247
# 8 Train Loss 0.000121046694 RD T: 0.049971658700011856 RD C: 0.023774561903602626
# 9 Train Loss 9.27469e-05 RD T: 0.047993655805332866 RD C: 0.022308309635329173
# 10 Train Loss 6.432306e-05 RD T: 0.04936612975065554 RD C: 0.023241768314685773
# 11 Train Loss 4.79868e-05 RD T: 0.05023379893886724 RD C: 0.02347312049673325
# 12 Train Loss 3.8188067e-05 RD T: 0.04974275167938389 RD C: 0.023319317100251917
# 13 Train Loss 3.4239056e-05 RD T: 0.049658415442442976 RD C: 0.023424909566893644
# 14 Train Loss 2.889144e-05 RD T: 0.0499976201419863 RD C: 0.023655462372937367
# 15 Train Loss 2.3382187e-05 RD T: 0.049913205436561525 RD C: 0.023516954370885097
# 16 Train Loss 1.8836326e-05 RD T: 0.04990321776492097 RD C: 0.023562631327982406
# 17 Train Loss 1.6572e-05 RD T: 0.049841323797819734 RD C: 0.02348094094157415
# 18 Train Loss 1.51282675e-05 RD T: 0.0496881884178915 RD C: 0.023345091481847196
# 19 Train Loss 1.4360003e-05 RD T: 0.04953402676263164 RD C: 0.023231618783600798
# 20 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 21 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 22 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 23 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 24 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 25 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 26 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 27 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 28 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 29 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 30 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 31 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 32 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 33 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 34 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 35 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 36 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 37 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 38 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 39 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 40 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 41 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 42 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 43 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 44 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 45 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 46 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 47 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 48 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 49 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 50 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 51 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 52 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 53 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 54 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 55 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 56 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 57 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 58 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 59 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 60 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 61 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 62 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 63 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 64 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 65 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 66 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 67 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 68 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 69 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 70 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 71 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 72 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 73 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 74 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 75 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 76 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 77 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 78 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 79 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 80 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 81 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 82 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 83 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 84 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 85 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 86 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 87 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 88 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 89 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 90 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 91 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 92 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 93 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 94 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 95 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 96 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 97 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 98 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# 99 Train Loss 1.37635925e-05 RD T: 0.049597369928410184 RD C: 0.023358569776469423
# Training time: 25.33

# %%
T_PINN,C_PINN = coPINN_trained.test()
s = T_FVM_2.shape
T_PINN = T_PINN.reshape(s[0],s[1])
C_PINN = C_PINN.reshape(s[0],s[1])

# %%
plt.plot(T_PINN[:,0])
plt.plot(T_FVM_2[:,0])

# %%
# print("T1 RMSD",np.sqrt(np.mean(np.square(T_FVM_1 - T_PINN))))
# print("C1 RMSD",np.sqrt(np.mean(np.square(C_FVM_1 - C_PINN))))

print("T2 RMSD",np.sqrt(np.mean(np.square(T_FVM_2 - T_PINN))))
print("C2 RMSD",np.sqrt(np.mean(np.square(C_FVM_2 - C_PINN))))
# Out:
# T2 RMSD 0.03573383642224356
# C2 RMSD 0.0182975063372724

# %%
fixed_params = {'xlabel': '$t$','ylabel': '$x$','extent': [0,L,0,t_end],
                'proposed_indicator': 2,'aspect':1}

data = [T_FVM_1,T_FVM_2,T_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Temperature $T(x,t)$'
save_name = "Temp_1D_Values"
vmax = np.max(T_PINN)
vmin = np.min(T_PINN)


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
data = [C_FVM_1,C_FVM_2,C_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Concentration $C(x,t)$'
save_name = "Conc_1D_Values"
vmax = np.max(C_PINN)
vmin = np.min(C_PINN)


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
opt = 'neutral'
interp_method = 'spline'

interp_layers = [2,50,50,50,50,1]
interp_device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
interp_max_iter = 5000

NN_constants = {"layers":interp_layers,"device":interp_device,"max_iter":interp_max_iter}



f1_PINN,f1_fvm_1,f2_PINN,f2_fvm_1 = res_compare(opt,interp_method,pde_related_funcs,problem_constants,
                                            N_x_2, t_steps_2,N_x_1,t_steps_1,T_FVM_1,C_FVM_1,coPINN_trained,device,
                                            NN_interp_constants=NN_constants)

f1_PINN,f1_fvm_2,f2_PINN,f2_fvm_2 = res_compare(opt,interp_method,pde_related_funcs,problem_constants,
                                            N_x_2, t_steps_2,N_x_2,t_steps_2,T_FVM_2,C_FVM_2,coPINN_trained,device,
                                            NN_interp_constants=NN_constants)
# Out:
# (200, 1001)
# (200, 1001)
# (200, 1001)
# PINN_f1: 0.0016
# FVM_f1: 0.0408
# PINN_f2: 0.0012
# FVM_f2: 0.0318
# (200, 1001)
# (200, 1001)
# (200, 1001)
# PINN_f1: 0.0017
# FVM_f1: 0.0044
# PINN_f2: 0.0013
# FVM_f2: 0.0040

# %%
problem_constants
# Out:
# {'L': 1.0,
#  'Max_time': 1,
#  'alpha': 0.01,
#  'beta': 1.0,
#  'gamma': 1.0,
#  'D': 0.01,
#  'forcing_func_torch': <function __main__.forcing_func_torch(x)>}

# %%
data = [f1_fvm_1,f1_fvm_2,f1_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Residual $f_h(x,t)$'
save_name = "Residuals_HeatEquation"
vmax = np.max(np.abs(f1_fvm_1))
vmin = 0


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
data = [f2_fvm_1,f2_fvm_2,f2_PINN]
title = ['Coarse FVM','Fine FVM','coPINN']
colorbar_label = 'Residuals $f_d(x,t)$'
save_name = "Residuals_DiffusionEquation"
# vmax = np.max(np.abs(f2_fvm))
vmax = 0.05
vmin = 0


plot_data = {"fixed_params": fixed_params,"data":data,'title':title,"vmax":vmax,"vmin":vmin,
             "colorbar_label":colorbar_label,"save_name":save_name}


save_imshow_sidebyside(plot_data)

# %%
loss_thresh = 25000
level = "_low"
label = "Burgers_coPINN_" 

x = np.linspace(0,1,N_x).reshape(-1,1)
t = np.linspace(0,t_max,t_steps).reshape(-1,1)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

lb_xt = xt[0]
ub_xt = xt[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       3 label = "Burgers_coPINN_"
#       5 x = np.linspace(0,1,N_x).reshape(-1,1)
# ----> 6 t = np.linspace(0,t_max,t_steps).reshape(-1,1)
#       8 X,T = np.meshgrid(x,t)
#      10 X = X.flatten('F').reshape(-1,1)
#
# NameError: name 't_max' is not defined

# %%
pi = torch.from_numpy(np.array(np.pi)).double().to(device)


x = np.linspace(0,1,N_x)
t = np.linspace(0,t_max,t_steps)

X,T = np.meshgrid(x,t)

X = X.flatten('F').reshape(-1,1)
T = T.flatten('F').reshape(-1,1)
  
xt = np.hstack((X,T))

# %%
#CHECKING RESIDUALS AND PLOTTING
#f2 = dC_dt - D*d2C_dx2 - gamma*T

# %%
#CHECKING RESIDUALS AND PLOTTING ~  GRID POINTS
f1_PINN,f1_FVM,f2_PINN,f2_FVM = res_compare('grid')
# Out:
# PINN_f1: 0.0019
# FVM_f1: 0.0069
# PINN_f2: 0.0014
# FVM_f2: 0.1048

# %%
np.mean(f2_FVM)
# Out:
# 5.4337797442834806e-15

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet
fig.tight_layout()



ax = axs[0]
img = ax.imshow(np.abs(f1_PINN),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.03)
ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


ax = axs[1]
img = ax.imshow(np.abs(f1_FVM),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.03)
ax.set_title('FVM $u(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


fig.tight_layout()
# plt.savefig('Burgers_test_u.svg',format = 'svg')
# plt.savefig('FSU_Burgers_test_u.svg',format = 'svg',bbox_inches = 'tight')

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet
fig.tight_layout()



ax = axs[0]
img = ax.imshow(np.abs(f2_PINN),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.01)
ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


ax = axs[1]
img = ax.imshow(np.abs(f2_FVM),interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmin = 0,vmax = 0.01)
ax.set_title('FVM $u(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


fig.tight_layout()

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet
fig.tight_layout()



ax = axs[0]
img = ax.imshow(T_PINN_matrix,interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


ax = axs[1]
img = ax.imshow(T_FVM_matrix,interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('FVM $u(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)


fig.tight_layout()
# plt.savefig('Burgers_test_u.svg',format = 'svg')
# plt.savefig('FSU_Burgers_test_u.svg',format = 'svg',bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       3 fig.tight_layout()
#       7 ax = axs[0]
# ----> 8 img = ax.imshow(T_PINN_matrix,interpolation= 'none',cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
#       9 ax.set_title('PINN $u(x,t)$',color = 'r',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
#      10 ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
#
# NameError: name 'T_PINN_matrix' is not defined

# %%
plt.plot(T_FVM_matrix[:,100],'b')
plt.plot(T_PINN_matrix[:,100],'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plt.plot(T_FVM_matrix[:,100],'b')
#       2 plt.plot(T_PINN_matrix[:,100],'r')
#
# NameError: name 'T_FVM_matrix' is not defined

# %%
fig, axs = plt.subplots(1,2)
cmap = plt.cm.jet



ax = axs[0]
img = ax.imshow(C_PINN_matrix,cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('PINN $T(x,t)$',math_fontfamily = 'cm', color = 'r',fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 14)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 14)
fig.tight_layout()


ax = axs[1]
img = ax.imshow(C_FVM_matrix,cmap = cmap,extent=[0,1,-1,1],aspect = 0.5,vmax = 1,vmin = -1)
ax.set_title('FVM $T(x,t)$',math_fontfamily = 'cm', fontsize = 18,fontweight = 'extra bold')
ax.set_xlabel('$t$',math_fontfamily = 'cm', fontsize = 12)
ax.set_ylabel('$x$',math_fontfamily = 'cm', fontsize = 12)


fig.tight_layout()
# plt.savefig('Burgers_test_T.svg',format = 'svg')
# plt.savefig('FSU_Burgers_test_T.svg',format = 'svg',bbox_inches = 'tight')
